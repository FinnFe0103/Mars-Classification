# %% [markdown]
# # 0. IMPORT STATEMENTS

# %%
# !pip install opencv-python
# !pip install scikit-learn
# !pip install imblearn
import cv2
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import RandomOverSampler
# Out:
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.9/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.0 in ./.venv/lib/python3.9/site-packages (from opencv-python) (1.24.3)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in ./.venv/lib/python3.9/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in ./.venv/lib/python3.9/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in ./.venv/lib/python3.9/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Collecting imblearn
#   Using cached imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Requirement already satisfied: imbalanced-learn in ./.venv/lib/python3.9/site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in ./.venv/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in ./.venv/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in ./.venv/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in ./.venv/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (3.1.0)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0

# %% [markdown]
# # 1. READ-IN DATA TO DF

# %%
df = pd.read_csv("labels-map-proj_v3_2.txt", sep=" ", header=None, names=["image", "label"])

# filter all images that end with fv, brt, r90, r180, r270, and fh
df = df[~df["image"].str.contains("fv|brt|r90|r180|r270|fh")]
print(df.shape)
df.head(5)
# Out:
# (10815, 2)
#                            image  label
# 0   ESP_013049_0950_RED-0067.jpg      7
# 7   ESP_019697_2020_RED-0024.jpg      1
# 14  ESP_015962_1695_RED-0016.jpg      1
# 21  ESP_013049_0950_RED-0118.jpg      7
# 28  ESP_015962_1695_RED-0017.jpg      1

# %%
df["label"].value_counts()
# Out:
# label
# 0    8802
# 1     794
# 6     298
# 3     267
# 4     250
# 2     166
# 7     164
# 5      74
# Name: count, dtype: int64

# %% [markdown]
# # 2. DELETE 8k RANDOM IMAGES & SHUFFLE

# %%
# delte 7802 random images from the category with label 0
df_us = df.drop(df[df["label"] == 0].sample(7702, random_state=1).index)
df_us["label"].value_counts()
# Out:
# label
# 0    1100
# 1     794
# 6     298
# 3     267
# 4     250
# 2     166
# 7     164
# 5      74
# Name: count, dtype: int64

# %%
# shuffle the dataframe
df_us = df_us.sample(frac=1, random_state=1).reset_index(drop=True)
df_us.head(5)
# Out:
#                           image  label
# 0  ESP_018720_2655_RED-0035.jpg      2
# 1  ESP_046991_0950_RED-0024.jpg      7
# 2  ESP_039350_1915_RED-0186.jpg      1
# 3  ESP_014156_1865_RED-0023.jpg      3
# 4  ESP_013049_0950_RED-0088.jpg      7

# %% [markdown]
# # 3. READ-IN TO PIXELS

# %%
def load_images_labels_from_df(df, folder):
    images = []
    labels = []
    for i in range(len(df)):
        img = cv2.imread(folder+"/"+df.iloc[i][0], cv2.IMREAD_GRAYSCALE)
        if img is not None:
            images.append(img)
            labels.append(df.iloc[i][1])
    return np.array(images), np.array(labels)

# %%
X, y = load_images_labels_from_df(df_us, "map-proj-v3_2")
unique, counts = np.unique(y, return_counts=True)
print(unique, counts)
print(X.shape[0])
# Out:
# [0 1 2 3 4 5 6 7] [1100  794  166  267  250   74  298  164]
# 3113

# %% [markdown]
# # 4. NORMALIZE DATA TO 0-1

# %%
X_norm = X / 255.0
print(X_norm.min())
print(X_norm.max())
# Out:
# 0.0
# 1.0

# %% [markdown]
# # 5. TRAIN-TEST SPLIT

# %%
X_train, X_temp, y_train, y_temp = train_test_split(X_norm, y, test_size=0.4, random_state=42)
X_test, X_val, y_test, y_val = train_test_split(X_temp, y_temp, test_size=0.3, random_state=42)
print(X_train.shape, y_train.shape, "Train")
print(X_test.shape, y_test.shape, "Test")
print(X_val.shape, y_val.shape, "Validation")
# Out:
# (1867, 227, 227) (1867,) Train
# (872, 227, 227) (872,) Test
# (374, 227, 227) (374,) Validation

# %%
print(np.unique(y_train, return_counts=True))
print(np.unique(y_train, return_counts=True)[1]/y_train.shape[0])

print(np.unique(y_test, return_counts=True))
print(np.unique(y_test, return_counts=True)[1]/y_test.shape[0])
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]), array([690, 452,  92, 168, 153,  41, 180,  91]))
# [0.36957686 0.24209963 0.04927691 0.08998393 0.08194965 0.02196036
#  0.09641136 0.0487413 ]
# (array([0, 1, 2, 3, 4, 5, 6, 7]), array([299, 238,  51,  66,  66,  24,  77,  51]))
# [0.34288991 0.27293578 0.05848624 0.07568807 0.07568807 0.02752294
#  0.08830275 0.05848624]

# %% [markdown]
# # 6. IMBALANCE HANDLING

# %% [markdown]
# ## 6.0 Flatten Images

# %%
X_reshaped = X_train.flatten().reshape(X_train.shape[0], 51529)
print(X_train.shape)
print(X_reshaped.shape)
# Out:
# (1867, 227, 227)
# (1867, 51529)

# %% [markdown]
# ## 6.1 ADASYN

# %%
adasyn = ADASYN(sampling_strategy="not majority", random_state=1)
X_train_adasyn, y_train_adasyn = adasyn.fit_resample(X_reshaped, y_train) # type: ignore

# %% [markdown]
# ## 6.2 OVERSAMPLING

# %%
oversampler = RandomOverSampler(sampling_strategy="not majority", random_state=3)
X_resampled, y_resampled = oversampler.fit_resample(X_reshaped, y_train) # type: ignore

# %%
l1 = pd.DataFrame(X_resampled[np.where(y_resampled == 1)[0]])
print(f"Number of duplicates for the first label after oversampling: {l1.duplicated().sum()}")
all_l = pd.DataFrame(X_resampled)
print(f"Number of duplicates for all labels after oversampling: {all_l.duplicated().sum()}")
# Out:
# Number of duplicates for the first label after oversampling: 238
# Number of duplicates for all labels after oversampling: 3653

# %%
unique, counts = np.unique(y_train, return_counts=True)
unique_a, counts_a = np.unique(y_train_adasyn, return_counts=True)
unique_b, counts_b = np.unique(y_resampled, return_counts=True)
print(X_train_adasyn.shape)
print(unique, counts)
print(unique_a, counts_a)
print(unique_b, counts_b)
# Out:
# (5482, 51529)
# [0 1 2 3 4 5 6 7] [690 452  92 168 153  41 180  91]
# [0 1 2 3 4 5 6 7] [690 651 690 685 668 681 723 694]
# [0 1 2 3 4 5 6 7] [690 690 690 690 690 690 690 690]

# %%
X_t_A = X_train_adasyn.reshape(X_train_adasyn.shape[0], 227, 227) # type: ignore
y_t_A = y_train_adasyn

X_t_O = X_resampled.reshape(X_resampled.shape[0], 227, 227) # type: ignore
y_t_O = y_resampled

print(f"Shape of training instances generated by ADASYN: \n{X_t_A.shape}, correspoding y: {y_t_A.shape}")
print(f"Shape of training instances generated by RandomOverSampler: \n{X_t_O.shape}, correspoding y: {y_t_O.shape}")
# Out:
# Shape of training instances generated by ADASYN:
# (5482, 227, 227), correspoding y: (5482,)
# Shape of training instances generated by RandomOverSampler:
# (5520, 227, 227), correspoding y: (5520,)

# %% [markdown]
# # 7. AUGMENTATION
# 1. Rotate 90
# 2. Rotate 180
# 3. Rotate 270
# 4. Flip Horizontally
# 5. Flip Vertically
# 6. Zoom

# %%
def zoom_at(img, zoom=1.0):
    h, w, = [zoom * i for i in img.shape]
    cx, cy = w/2, h/2
    img = cv2.resize( img, (0, 0), fx=zoom, fy=zoom)
    img = img[int(round(cy - h/zoom * .5)) : int(round(cy + h/zoom * .5)),
              int(round(cx - w/zoom * .5)) : int(round(cx + w/zoom * .5))]
    return img

def augment_images(images, labels):
    """
    Augments a numpy array of images by rotating them by 90, 180, and 270 degrees, flipping them horizontally and
    vertically, and zooming in on them.
    
    Args:
    - images (numpy.ndarray): A numpy array of shape (N, H, W, C), where N is the number of images, H and W are the
                              height and width of the images, and C is the number of color channels.
                              
    Returns:
    - augmented_images (numpy.ndarray): A numpy array of shape (7N, H, W, C), where the first N images are the
                                         original images and the remaining 6N images are the augmented images.
    """
    # Initialize an empty numpy array to store the augmented images
    augmented_images = np.empty((7*images.shape[0], images.shape[1], images.shape[2]))
    augmented_labels = np.empty((7*images.shape[0]))
    

    # Loop through each image in the array and perform the augmentations
    for i in range(images.shape[0]):
        image = images[i]
        label = labels[i]

        # Add the original image to the output array
        augmented_images[(i*7)] = image
        augmented_labels[(i*7)] = label
        
        # Rotate the image by 90 degrees
        rotated_90 = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
        augmented_images[(i*7)+1] = rotated_90
        augmented_labels[(i*7)+1] = label
        
        # Rotate the image by 180 degrees
        rotated_180 = cv2.rotate(image, cv2.ROTATE_180)
        augmented_images[(i*7)+2] = rotated_180
        augmented_labels[(i*7)+2] = label
        
        # Rotate the image by 270 degrees
        rotated_270 = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE)
        augmented_images[(i*7)+3] = rotated_270
        augmented_labels[(i*7)+3] = label
        
        # Flip the image horizontally
        flipped_horizontal = cv2.flip(image, 1)
        augmented_images[(i*7)+4] = flipped_horizontal
        augmented_labels[(i*7)+4] = label
        
        # Flip the image vertically
        flipped_vertical = cv2.flip(image, 0)
        augmented_images[(i*7)+5] = flipped_vertical
        augmented_labels[(i*7)+5] = label
        
        # Zoom in on the image
        zoomed_in = zoom_at(image, 1.2)
        augmented_images[(i*7)+6] = zoomed_in
        augmented_labels[(i*7)+6] = label

        print(f"Image, {i} done")

    return augmented_images, augmented_labels

# %%
X_t_A_A, y_t_A_A = augment_images(X_t_A, y_t_A)
X_t_O_A, y_t_O_A = augment_images(X_t_O, y_t_O)
print(f"Shape of original training data for ADASYN: {X_t_A.shape} with corresponding y: {y_t_A.shape}")
print(f"Shape of augmented training data for ADASYN: {X_t_A_A.shape} with corresponding y: {y_t_A_A.shape}")
print(f"Shape of original training data for RandomOverSampler: {X_t_O.shape} with corresponding y: {y_t_O.shape}")
print(f"Shape of augmented training data for RandomOverSampler: {X_t_O_A.shape} with corresponding y: {y_t_O_A.shape}")
# Out:
# Image, 0 done
# Image, 1 done
# Image, 2 done
# Image, 3 done
# Image, 4 done
# Image, 5 done
# Image, 6 done
# Image, 7 done
# Image, 8 done
# Image, 9 done
# Image, 10 done
# Image, 11 done
# Image, 12 done
# Image, 13 done
# Image, 14 done
# Image, 15 done
# Image, 16 done
# Image, 17 done
# Image, 18 done
# Image, 19 done
# Image, 20 done
# Image, 21 done
# Image, 22 done
# Image, 23 done
# Image, 24 done
# Image, 25 done
# Image, 26 done
# Image, 27 done
# Image, 28 done
# Image, 29 done
# Image, 30 done
# Image, 31 done
# Image, 32 done
# Image, 33 done
# Image, 34 done
# Image, 35 done
# Image, 36 done
# Image, 37 done
# Image, 38 done
# Image, 39 done
# Image, 40 done
# Image, 41 done
# Image, 42 done
# Image, 43 done
# Image, 44 done
# Image, 45 done
# Image, 46 done
# Image, 47 done
# Image, 48 done
# Image, 49 done
# Image, 50 done
# Image, 51 done
# Image, 52 done
# Image, 53 done
# Image, 54 done
# Image, 55 done
# Image, 56 done
# Image, 57 done
# Image, 58 done
# Image, 59 done
# Image, 60 done
# Image, 61 done
# Image, 62 done
# Image, 63 done
# Image, 64 done
# Image, 65 done
# Image, 66 done
# Image, 67 done
# Image, 68 done
# Image, 69 done
# Image, 70 done
# Image, 71 done
# Image, 72 done
# Image, 73 done
# Image, 74 done
# Image, 75 done
# Image, 76 done
# Image, 77 done
# Image, 78 done
# Image, 79 done
# Image, 80 done
# Image, 81 done
# Image, 82 done
# Image, 83 done
# Image, 84 done
# Image, 85 done
# Image, 86 done
# Image, 87 done
# Image, 88 done
# Image, 89 done
# Image, 90 done
# Image, 91 done
# Image, 92 done
# Image, 93 done
# Image, 94 done
# Image, 95 done
# Image, 96 done
# Image, 97 done
# Image, 98 done
# Image, 99 done
# Image, 100 done
# Image, 101 done
# Image, 102 done
# Image, 103 done
# Image, 104 done
# Image, 105 done
# Image, 106 done
# Image, 107 done
# Image, 108 done
# Image, 109 done
# Image, 110 done
# Image, 111 done
# Image, 112 done
# Image, 113 done
# Image, 114 done
# Image, 115 done
# Image, 116 done
# Image, 117 done
# Image, 118 done
# Image, 119 done
# Image, 120 done
# Image, 121 done
# Image, 122 done
# Image, 123 done
# Image, 124 done
# Image, 125 done
# Image, 126 done
# Image, 127 done
# Image, 128 done
# Image, 129 done
# Image, 130 done
# Image, 131 done
# Image, 132 done
# Image, 133 done
# Image, 134 done
# Image, 135 done
# Image, 136 done
# Image, 137 done
# Image, 138 done
# Image, 139 done
# Image, 140 done
# Image, 141 done
# Image, 142 done
# Image, 143 done
# Image, 144 done
# Image, 145 done
# Image, 146 done
# Image, 147 done
# Image, 148 done
# Image, 149 done
# Image, 150 done
# Image, 151 done
# Image, 152 done
# Image, 153 done
# Image, 154 done
# Image, 155 done
# Image, 156 done
# Image, 157 done
# Image, 158 done
# Image, 159 done
# Image, 160 done
# Image, 161 done
# Image, 162 done
# Image, 163 done
# Image, 164 done
# Image, 165 done
# Image, 166 done
# Image, 167 done
# Image, 168 done
# Image, 169 done
# Image, 170 done
# Image, 171 done
# Image, 172 done
# Image, 173 done
# Image, 174 done
# Image, 175 done
# Image, 176 done
# Image, 177 done
# Image, 178 done
# Image, 179 done
# Image, 180 done
# Image, 181 done
# Image, 182 done
# Image, 183 done
# Image, 184 done
# Image, 185 done
# Image, 186 done
# Image, 187 done
# Image, 188 done
# Image, 189 done
# Image, 190 done
# Image, 191 done
# Image, 192 done
# Image, 193 done
# Image, 194 done
# Image, 195 done
# Image, 196 done
# Image, 197 done
# Image, 198 done
# Image, 199 done
# Image, 200 done
# Image, 201 done
# Image, 202 done
# Image, 203 done
# Image, 204 done
# Image, 205 done
# Image, 206 done
# Image, 207 done
# Image, 208 done
# Image, 209 done
# Image, 210 done
# Image, 211 done
# Image, 212 done
# Image, 213 done
# Image, 214 done
# Image, 215 done
# Image, 216 done
# Image, 217 done
# Image, 218 done
# Image, 219 done
# Image, 220 done
# Image, 221 done
# Image, 222 done
# Image, 223 done
# Image, 224 done
# Image, 225 done
# Image, 226 done
# Image, 227 done
# Image, 228 done
# Image, 229 done
# Image, 230 done
# Image, 231 done
# Image, 232 done
# Image, 233 done
# Image, 234 done
# Image, 235 done
# Image, 236 done
# Image, 237 done
# Image, 238 done
# Image, 239 done
# Image, 240 done
# Image, 241 done
# Image, 242 done
# Image, 243 done
# Image, 244 done
# Image, 245 done
# Image, 246 done
# Image, 247 done
# Image, 248 done
# Image, 249 done
# Image, 250 done
# Image, 251 done
# Image, 252 done
# Image, 253 done
# Image, 254 done
# Image, 255 done
# Image, 256 done
# Image, 257 done
# Image, 258 done
# Image, 259 done
# Image, 260 done
# Image, 261 done
# Image, 262 done
# Image, 263 done
# Image, 264 done
# Image, 265 done
# Image, 266 done
# Image, 267 done
# Image, 268 done
# Image, 269 done
# Image, 270 done
# Image, 271 done
# Image, 272 done
# Image, 273 done
# Image, 274 done
# Image, 275 done
# Image, 276 done
# Image, 277 done
# Image, 278 done
# Image, 279 done
# Image, 280 done
# Image, 281 done
# Image, 282 done
# Image, 283 done
# Image, 284 done
# Image, 285 done
# Image, 286 done
# Image, 287 done
# Image, 288 done
# Image, 289 done
# Image, 290 done
# Image, 291 done
# Image, 292 done
# Image, 293 done
# Image, 294 done
# Image, 295 done
# Image, 296 done
# Image, 297 done
# Image, 298 done
# Image, 299 done
# Image, 300 done
# Image, 301 done
# Image, 302 done
# Image, 303 done
# Image, 304 done
# Image, 305 done
# Image, 306 done
# Image, 307 done
# Image, 308 done
# Image, 309 done
# Image, 310 done
# Image, 311 done
# Image, 312 done
# Image, 313 done
# Image, 314 done
# Image, 315 done
# Image, 316 done
# Image, 317 done
# Image, 318 done
# Image, 319 done
# Image, 320 done
# Image, 321 done
# Image, 322 done
# Image, 323 done
# Image, 324 done
# Image, 325 done
# Image, 326 done
# Image, 327 done
# Image, 328 done
# Image, 329 done
# Image, 330 done
# Image, 331 done
# Image, 332 done
# Image, 333 done
# Image, 334 done
# Image, 335 done
# Image, 336 done
# Image, 337 done
# Image, 338 done
# Image, 339 done
# Image, 340 done
# Image, 341 done
# Image, 342 done
# Image, 343 done
# Image, 344 done
# Image, 345 done
# Image, 346 done
# Image, 347 done
# Image, 348 done
# Image, 349 done
# Image, 350 done
# Image, 351 done
# Image, 352 done
# Image, 353 done
# Image, 354 done
# Image, 355 done
# Image, 356 done
# Image, 357 done
# Image, 358 done
# Image, 359 done
# Image, 360 done
# Image, 361 done
# Image, 362 done
# Image, 363 done
# Image, 364 done
# Image, 365 done
# Image, 366 done
# Image, 367 done
# Image, 368 done
# Image, 369 done
# Image, 370 done
# Image, 371 done
# Image, 372 done
# Image, 373 done
# Image, 374 done
# Image, 375 done
# Image, 376 done
# Image, 377 done
# Image, 378 done
# Image, 379 done
# Image, 380 done
# Image, 381 done
# Image, 382 done
# Image, 383 done
# Image, 384 done
# Image, 385 done
# Image, 386 done
# Image, 387 done
# Image, 388 done
# Image, 389 done
# Image, 390 done
# Image, 391 done
# Image, 392 done
# Image, 393 done
# Image, 394 done
# Image, 395 done
# Image, 396 done
# Image, 397 done
# Image, 398 done
# Image, 399 done
# Image, 400 done
# Image, 401 done
# Image, 402 done
# Image, 403 done
# Image, 404 done
# Image, 405 done
# Image, 406 done
# Image, 407 done
# Image, 408 done
# Image, 409 done
# Image, 410 done
# Image, 411 done
# Image, 412 done
# Image, 413 done
# Image, 414 done
# Image, 415 done
# Image, 416 done
# Image, 417 done
# Image, 418 done
# Image, 419 done
# Image, 420 done
# Image, 421 done
# Image, 422 done
# Image, 423 done
# Image, 424 done
# Image, 425 done
# Image, 426 done
# Image, 427 done
# Image, 428 done
# Image, 429 done
# Image, 430 done
# Image, 431 done
# Image, 432 done
# Image, 433 done
# Image, 434 done
# Image, 435 done
# Image, 436 done
# Image, 437 done
# Image, 438 done
# Image, 439 done
# Image, 440 done
# Image, 441 done
# Image, 442 done
# Image, 443 done
# Image, 444 done
# Image, 445 done
# Image, 446 done
# Image, 447 done
# Image, 448 done
# Image, 449 done
# Image, 450 done
# Image, 451 done
# Image, 452 done
# Image, 453 done
# Image, 454 done
# Image, 455 done
# Image, 456 done
# Image, 457 done
# Image, 458 done
# Image, 459 done
# Image, 460 done
# Image, 461 done
# Image, 462 done
# Image, 463 done
# Image, 464 done
# Image, 465 done
# Image, 466 done
# Image, 467 done
# Image, 468 done
# Image, 469 done
# Image, 470 done
# Image, 471 done
# Image, 472 done
# Image, 473 done
# Image, 474 done
# Image, 475 done
# Image, 476 done
# Image, 477 done
# Image, 478 done
# Image, 479 done
# Image, 480 done
# Image, 481 done
# Image, 482 done
# Image, 483 done
# Image, 484 done
# Image, 485 done
# Image, 486 done
# Image, 487 done
# Image, 488 done
# Image, 489 done
# Image, 490 done
# Image, 491 done
# Image, 492 done
# Image, 493 done
# Image, 494 done
# Image, 495 done
# Image, 496 done
# Image, 497 done
# Image, 498 done
# Image, 499 done
# Image, 500 done
# Image, 501 done
# Image, 502 done
# Image, 503 done
# Image, 504 done
# Image, 505 done
# Image, 506 done
# Image, 507 done
# Image, 508 done
# Image, 509 done
# Image, 510 done
# Image, 511 done
# Image, 512 done
# Image, 513 done
# Image, 514 done
# Image, 515 done
# Image, 516 done
# Image, 517 done
# Image, 518 done
# Image, 519 done
# Image, 520 done
# Image, 521 done
# Image, 522 done
# Image, 523 done
# Image, 524 done
# Image, 525 done
# Image, 526 done
# Image, 527 done
# Image, 528 done
# Image, 529 done
# Image, 530 done
# Image, 531 done
# Image, 532 done
# Image, 533 done
# Image, 534 done
# Image, 535 done
# Image, 536 done
# Image, 537 done
# Image, 538 done
# Image, 539 done
# Image, 540 done
# Image, 541 done
# Image, 542 done
# Image, 543 done
# Image, 544 done
# Image, 545 done
# Image, 546 done
# Image, 547 done
# Image, 548 done
# Image, 549 done
# Image, 550 done
# Image, 551 done
# Image, 552 done
# Image, 553 done
# Image, 554 done
# Image, 555 done
# Image, 556 done
# Image, 557 done
# Image, 558 done
# Image, 559 done
# Image, 560 done
# Image, 561 done
# Image, 562 done
# Image, 563 done
# Image, 564 done
# Image, 565 done
# Image, 566 done
# Image, 567 done
# Image, 568 done
# Image, 569 done
# Image, 570 done
# Image, 571 done
# Image, 572 done
# Image, 573 done
# Image, 574 done
# Image, 575 done
# Image, 576 done
# Image, 577 done
# Image, 578 done
# Image, 579 done
# Image, 580 done
# Image, 581 done
# Image, 582 done
# Image, 583 done
# Image, 584 done
# Image, 585 done
# Image, 586 done
# Image, 587 done
# Image, 588 done
# Image, 589 done
# Image, 590 done
# Image, 591 done
# Image, 592 done
# Image, 593 done
# Image, 594 done
# Image, 595 done
# Image, 596 done
# Image, 597 done
# Image, 598 done
# Image, 599 done
# Image, 600 done
# Image, 601 done
# Image, 602 done
# Image, 603 done
# Image, 604 done
# Image, 605 done
# Image, 606 done
# Image, 607 done
# Image, 608 done
# Image, 609 done
# Image, 610 done
# Image, 611 done
# Image, 612 done
# Image, 613 done
# Image, 614 done
# Image, 615 done
# Image, 616 done
# Image, 617 done
# Image, 618 done
# Image, 619 done
# Image, 620 done
# Image, 621 done
# Image, 622 done
# Image, 623 done
# Image, 624 done
# Image, 625 done
# Image, 626 done
# Image, 627 done
# Image, 628 done
# Image, 629 done
# Image, 630 done
# Image, 631 done
# Image, 632 done
# Image, 633 done
# Image, 634 done
# Image, 635 done
# Image, 636 done
# Image, 637 done
# Image, 638 done
# Image, 639 done
# Image, 640 done
# Image, 641 done
# Image, 642 done
# Image, 643 done
# Image, 644 done
# Image, 645 done
# Image, 646 done
# Image, 647 done
# Image, 648 done
# Image, 649 done
# Image, 650 done
# Image, 651 done
# Image, 652 done
# Image, 653 done
# Image, 654 done
# Image, 655 done
# Image, 656 done
# Image, 657 done
# Image, 658 done
# Image, 659 done
# Image, 660 done
# Image, 661 done
# Image, 662 done
# Image, 663 done
# Image, 664 done
# Image, 665 done
# Image, 666 done
# Image, 667 done
# Image, 668 done
# Image, 669 done
# Image, 670 done
# Image, 671 done
# Image, 672 done
# Image, 673 done
# Image, 674 done
# Image, 675 done
# Image, 676 done
# Image, 677 done
# Image, 678 done
# Image, 679 done
# Image, 680 done
# Image, 681 done
# Image, 682 done
# Image, 683 done
# Image, 684 done
# Image, 685 done
# Image, 686 done
# Image, 687 done
# Image, 688 done
# Image, 689 done
# Image, 690 done
# Image, 691 done
# Image, 692 done
# Image, 693 done
# Image, 694 done
# Image, 695 done
# Image, 696 done
# Image, 697 done
# Image, 698 done
# Image, 699 done
# Image, 700 done
# Image, 701 done
# Image, 702 done
# Image, 703 done
# Image, 704 done
# Image, 705 done
# Image, 706 done
# Image, 707 done
# Image, 708 done
# Image, 709 done
# Image, 710 done
# Image, 711 done
# Image, 712 done
# Image, 713 done
# Image, 714 done
# Image, 715 done
# Image, 716 done
# Image, 717 done
# Image, 718 done
# Image, 719 done
# Image, 720 done
# Image, 721 done
# Image, 722 done
# Image, 723 done
# Image, 724 done
# Image, 725 done
# Image, 726 done
# Image, 727 done
# Image, 728 done
# Image, 729 done
# Image, 730 done
# Image, 731 done
# Image, 732 done
# Image, 733 done
# Image, 734 done
# Image, 735 done
# Image, 736 done
# Image, 737 done
# Image, 738 done
# Image, 739 done
# Image, 740 done
# Image, 741 done
# Image, 742 done
# Image, 743 done
# Image, 744 done
# Image, 745 done
# Image, 746 done
# Image, 747 done
# Image, 748 done
# Image, 749 done
# Image, 750 done
# Image, 751 done
# Image, 752 done
# Image, 753 done
# Image, 754 done
# Image, 755 done
# Image, 756 done
# Image, 757 done
# Image, 758 done
# Image, 759 done
# Image, 760 done
# Image, 761 done
# Image, 762 done
# Image, 763 done
# Image, 764 done
# Image, 765 done
# Image, 766 done
# Image, 767 done
# Image, 768 done
# Image, 769 done
# Image, 770 done
# Image, 771 done
# Image, 772 done
# Image, 773 done
# Image, 774 done
# Image, 775 done
# Image, 776 done
# Image, 777 done
# Image, 778 done
# Image, 779 done
# Image, 780 done
# Image, 781 done
# Image, 782 done
# Image, 783 done
# Image, 784 done
# Image, 785 done
# Image, 786 done
# Image, 787 done
# Image, 788 done
# Image, 789 done
# Image, 790 done
# Image, 791 done
# Image, 792 done
# Image, 793 done
# Image, 794 done
# Image, 795 done
# Image, 796 done
# Image, 797 done
# Image, 798 done
# Image, 799 done
# Image, 800 done
# Image, 801 done
# Image, 802 done
# Image, 803 done
# Image, 804 done
# Image, 805 done
# Image, 806 done
# Image, 807 done
# Image, 808 done
# Image, 809 done
# Image, 810 done
# Image, 811 done
# Image, 812 done
# Image, 813 done
# Image, 814 done
# Image, 815 done
# Image, 816 done
# Image, 817 done
# Image, 818 done
# Image, 819 done
# Image, 820 done
# Image, 821 done
# Image, 822 done
# Image, 823 done
# Image, 824 done
# Image, 825 done
# Image, 826 done
# Image, 827 done
# Image, 828 done
# Image, 829 done
# Image, 830 done
# Image, 831 done
# Image, 832 done
# Image, 833 done
# Image, 834 done
# Image, 835 done
# Image, 836 done
# Image, 837 done
# Image, 838 done
# Image, 839 done
# Image, 840 done
# Image, 841 done
# Image, 842 done
# Image, 843 done
# Image, 844 done
# Image, 845 done
# Image, 846 done
# Image, 847 done
# Image, 848 done
# Image, 849 done
# Image, 850 done
# Image, 851 done
# Image, 852 done
# Image, 853 done
# Image, 854 done
# Image, 855 done
# Image, 856 done
# Image, 857 done
# Image, 858 done
# Image, 859 done
# Image, 860 done
# Image, 861 done
# Image, 862 done
# Image, 863 done
# Image, 864 done
# Image, 865 done
# Image, 866 done
# Image, 867 done
# Image, 868 done
# Image, 869 done
# Image, 870 done
# Image, 871 done
# Image, 872 done
# Image, 873 done
# Image, 874 done
# Image, 875 done
# Image, 876 done
# Image, 877 done
# Image, 878 done
# Image, 879 done
# Image, 880 done
# Image, 881 done
# Image, 882 done
# Image, 883 done
# Image, 884 done
# Image, 885 done
# Image, 886 done
# Image, 887 done
# Image, 888 done
# Image, 889 done
# Image, 890 done
# Image, 891 done
# Image, 892 done
# Image, 893 done
# Image, 894 done
# Image, 895 done
# Image, 896 done
# Image, 897 done
# Image, 898 done
# Image, 899 done
# Image, 900 done
# Image, 901 done
# Image, 902 done
# Image, 903 done
# Image, 904 done
# Image, 905 done
# Image, 906 done
# Image, 907 done
# Image, 908 done
# Image, 909 done
# Image, 910 done
# Image, 911 done
# Image, 912 done
# Image, 913 done
# Image, 914 done
# Image, 915 done
# Image, 916 done
# Image, 917 done
# Image, 918 done
# Image, 919 done
# Image, 920 done
# Image, 921 done
# Image, 922 done
# Image, 923 done
# Image, 924 done
# Image, 925 done
# Image, 926 done
# Image, 927 done
# Image, 928 done
# Image, 929 done
# Image, 930 done
# Image, 931 done
# Image, 932 done
# Image, 933 done
# Image, 934 done
# Image, 935 done
# Image, 936 done
# Image, 937 done
# Image, 938 done
# Image, 939 done
# Image, 940 done
# Image, 941 done
# Image, 942 done
# Image, 943 done
# Image, 944 done
# Image, 945 done
# Image, 946 done
# Image, 947 done
# Image, 948 done
# Image, 949 done
# Image, 950 done
# Image, 951 done
# Image, 952 done
# Image, 953 done
# Image, 954 done
# Image, 955 done
# Image, 956 done
# Image, 957 done
# Image, 958 done
# Image, 959 done
# Image, 960 done
# Image, 961 done
# Image, 962 done
# Image, 963 done
# Image, 964 done
# Image, 965 done
# Image, 966 done
# Image, 967 done
# Image, 968 done
# Image, 969 done
# Image, 970 done
# Image, 971 done
# Image, 972 done
# Image, 973 done
# Image, 974 done
# Image, 975 done
# Image, 976 done
# Image, 977 done
# Image, 978 done
# Image, 979 done
# Image, 980 done
# Image, 981 done
# Image, 982 done
# Image, 983 done
# Image, 984 done
# Image, 985 done
# Image, 986 done
# Image, 987 done
# Image, 988 done
# Image, 989 done
# Image, 990 done
# Image, 991 done
# Image, 992 done
# Image, 993 done
# Image, 994 done
# Image, 995 done
# Image, 996 done
# Image, 997 done
# Image, 998 done
# Image, 999 done
# Image, 1000 done
# Image, 1001 done
# Image, 1002 done
# Image, 1003 done
# Image, 1004 done
# Image, 1005 done
# Image, 1006 done
# Image, 1007 done
# Image, 1008 done
# Image, 1009 done
# Image, 1010 done
# Image, 1011 done
# Image, 1012 done
# Image, 1013 done
# Image, 1014 done
# Image, 1015 done
# Image, 1016 done
# Image, 1017 done
# Image, 1018 done
# Image, 1019 done
# Image, 1020 done
# Image, 1021 done
# Image, 1022 done
# Image, 1023 done
# Image, 1024 done
# Image, 1025 done
# Image, 1026 done
# Image, 1027 done
# Image, 1028 done
# Image, 1029 done
# Image, 1030 done
# Image, 1031 done
# Image, 1032 done
# Image, 1033 done
# Image, 1034 done
# Image, 1035 done
# Image, 1036 done
# Image, 1037 done
# Image, 1038 done
# Image, 1039 done
# Image, 1040 done
# Image, 1041 done
# Image, 1042 done
# Image, 1043 done
# Image, 1044 done
# Image, 1045 done
# Image, 1046 done
# Image, 1047 done
# Image, 1048 done
# Image, 1049 done
# Image, 1050 done
# Image, 1051 done
# Image, 1052 done
# Image, 1053 done
# Image, 1054 done
# Image, 1055 done
# Image, 1056 done
# Image, 1057 done
# Image, 1058 done
# Image, 1059 done
# Image, 1060 done
# Image, 1061 done
# Image, 1062 done
# Image, 1063 done
# Image, 1064 done
# Image, 1065 done
# Image, 1066 done
# Image, 1067 done
# Image, 1068 done
# Image, 1069 done
# Image, 1070 done
# Image, 1071 done
# Image, 1072 done
# Image, 1073 done
# Image, 1074 done
# Image, 1075 done
# Image, 1076 done
# Image, 1077 done
# Image, 1078 done
# Image, 1079 done
# Image, 1080 done
# Image, 1081 done
# Image, 1082 done
# Image, 1083 done
# Image, 1084 done
# Image, 1085 done
# Image, 1086 done
# Image, 1087 done
# Image, 1088 done
# Image, 1089 done
# Image, 1090 done
# Image, 1091 done
# Image, 1092 done
# Image, 1093 done
# Image, 1094 done
# Image, 1095 done
# Image, 1096 done
# Image, 1097 done
# Image, 1098 done
# Image, 1099 done
# Image, 1100 done
# Image, 1101 done
# Image, 1102 done
# Image, 1103 done
# Image, 1104 done
# Image, 1105 done
# Image, 1106 done
# Image, 1107 done
# Image, 1108 done
# Image, 1109 done
# Image, 1110 done
# Image, 1111 done
# Image, 1112 done
# Image, 1113 done
# Image, 1114 done
# Image, 1115 done
# Image, 1116 done
# Image, 1117 done
# Image, 1118 done
# Image, 1119 done
# Image, 1120 done
# Image, 1121 done
# Image, 1122 done
# Image, 1123 done
# Image, 1124 done
# Image, 1125 done
# Image, 1126 done
# Image, 1127 done
# Image, 1128 done
# Image, 1129 done
# Image, 1130 done
# Image, 1131 done
# Image, 1132 done
# Image, 1133 done
# Image, 1134 done
# Image, 1135 done
# Image, 1136 done
# Image, 1137 done
# Image, 1138 done
# Image, 1139 done
# Image, 1140 done
# Image, 1141 done
# Image, 1142 done
# Image, 1143 done
# Image, 1144 done
# Image, 1145 done
# Image, 1146 done
# Image, 1147 done
# Image, 1148 done
# Image, 1149 done
# Image, 1150 done
# Image, 1151 done
# Image, 1152 done
# Image, 1153 done
# Image, 1154 done
# Image, 1155 done
# Image, 1156 done
# Image, 1157 done
# Image, 1158 done
# Image, 1159 done
# Image, 1160 done
# Image, 1161 done
# Image, 1162 done
# Image, 1163 done
# Image, 1164 done
# Image, 1165 done
# Image, 1166 done
# Image, 1167 done
# Image, 1168 done
# Image, 1169 done
# Image, 1170 done
# Image, 1171 done
# Image, 1172 done
# Image, 1173 done
# Image, 1174 done
# Image, 1175 done
# Image, 1176 done
# Image, 1177 done
# Image, 1178 done
# Image, 1179 done
# Image, 1180 done
# Image, 1181 done
# Image, 1182 done
# Image, 1183 done
# Image, 1184 done
# Image, 1185 done
# Image, 1186 done
# Image, 1187 done
# Image, 1188 done
# Image, 1189 done
# Image, 1190 done
# Image, 1191 done
# Image, 1192 done
# Image, 1193 done
# Image, 1194 done
# Image, 1195 done
# Image, 1196 done
# Image, 1197 done
# Image, 1198 done
# Image, 1199 done
# Image, 1200 done
# Image, 1201 done
# Image, 1202 done
# Image, 1203 done
# Image, 1204 done
# Image, 1205 done
# Image, 1206 done
# Image, 1207 done
# Image, 1208 done
# Image, 1209 done
# Image, 1210 done
# Image, 1211 done
# Image, 1212 done
# Image, 1213 done
# Image, 1214 done
# Image, 1215 done
# Image, 1216 done
# Image, 1217 done
# Image, 1218 done
# Image, 1219 done
# Image, 1220 done
# Image, 1221 done
# Image, 1222 done
# Image, 1223 done
# Image, 1224 done
# Image, 1225 done
# Image, 1226 done
# Image, 1227 done
# Image, 1228 done
# Image, 1229 done
# Image, 1230 done
# Image, 1231 done
# Image, 1232 done
# Image, 1233 done
# Image, 1234 done
# Image, 1235 done
# Image, 1236 done
# Image, 1237 done
# Image, 1238 done
# Image, 1239 done
# Image, 1240 done
# Image, 1241 done
# Image, 1242 done
# Image, 1243 done
# Image, 1244 done
# Image, 1245 done
# Image, 1246 done
# Image, 1247 done
# Image, 1248 done
# Image, 1249 done
# Image, 1250 done
# Image, 1251 done
# Image, 1252 done
# Image, 1253 done
# Image, 1254 done
# Image, 1255 done
# Image, 1256 done
# Image, 1257 done
# Image, 1258 done
# Image, 1259 done
# Image, 1260 done
# Image, 1261 done
# Image, 1262 done
# Image, 1263 done
# Image, 1264 done
# Image, 1265 done
# Image, 1266 done
# Image, 1267 done
# Image, 1268 done
# Image, 1269 done
# Image, 1270 done
# Image, 1271 done
# Image, 1272 done
# Image, 1273 done
# Image, 1274 done
# Image, 1275 done
# Image, 1276 done
# Image, 1277 done
# Image, 1278 done
# Image, 1279 done
# Image, 1280 done
# Image, 1281 done
# Image, 1282 done
# Image, 1283 done
# Image, 1284 done
# Image, 1285 done
# Image, 1286 done
# Image, 1287 done
# Image, 1288 done
# Image, 1289 done
# Image, 1290 done
# Image, 1291 done
# Image, 1292 done
# Image, 1293 done
# Image, 1294 done
# Image, 1295 done
# Image, 1296 done
# Image, 1297 done
# Image, 1298 done
# Image, 1299 done
# Image, 1300 done
# Image, 1301 done
# Image, 1302 done
# Image, 1303 done
# Image, 1304 done
# Image, 1305 done
# Image, 1306 done
# Image, 1307 done
# Image, 1308 done
# Image, 1309 done
# Image, 1310 done
# Image, 1311 done
# Image, 1312 done
# Image, 1313 done
# Image, 1314 done
# Image, 1315 done
# Image, 1316 done
# Image, 1317 done
# Image, 1318 done
# Image, 1319 done
# Image, 1320 done
# Image, 1321 done
# Image, 1322 done
# Image, 1323 done
# Image, 1324 done
# Image, 1325 done
# Image, 1326 done
# Image, 1327 done
# Image, 1328 done
# Image, 1329 done
# Image, 1330 done
# Image, 1331 done
# Image, 1332 done
# Image, 1333 done
# Image, 1334 done
# Image, 1335 done
# Image, 1336 done
# Image, 1337 done
# Image, 1338 done
# Image, 1339 done
# Image, 1340 done
# Image, 1341 done
# Image, 1342 done
# Image, 1343 done
# Image, 1344 done
# Image, 1345 done
# Image, 1346 done
# Image, 1347 done
# Image, 1348 done
# Image, 1349 done
# Image, 1350 done
# Image, 1351 done
# Image, 1352 done
# Image, 1353 done
# Image, 1354 done
# Image, 1355 done
# Image, 1356 done
# Image, 1357 done
# Image, 1358 done
# Image, 1359 done
# Image, 1360 done
# Image, 1361 done
# Image, 1362 done
# Image, 1363 done
# Image, 1364 done
# Image, 1365 done
# Image, 1366 done
# Image, 1367 done
# Image, 1368 done
# Image, 1369 done
# Image, 1370 done
# Image, 1371 done
# Image, 1372 done
# Image, 1373 done
# Image, 1374 done
# Image, 1375 done
# Image, 1376 done
# Image, 1377 done
# Image, 1378 done
# Image, 1379 done
# Image, 1380 done
# Image, 1381 done
# Image, 1382 done
# Image, 1383 done
# Image, 1384 done
# Image, 1385 done
# Image, 1386 done
# Image, 1387 done
# Image, 1388 done
# Image, 1389 done
# Image, 1390 done
# Image, 1391 done
# Image, 1392 done
# Image, 1393 done
# Image, 1394 done
# Image, 1395 done
# Image, 1396 done
# Image, 1397 done
# Image, 1398 done
# Image, 1399 done
# Image, 1400 done
# Image, 1401 done
# Image, 1402 done
# Image, 1403 done
# Image, 1404 done
# Image, 1405 done
# Image, 1406 done
# Image, 1407 done
# Image, 1408 done
# Image, 1409 done
# Image, 1410 done
# Image, 1411 done
# Image, 1412 done
# Image, 1413 done
# Image, 1414 done
# Image, 1415 done
# Image, 1416 done
# Image, 1417 done
# Image, 1418 done
# Image, 1419 done
# Image, 1420 done
# Image, 1421 done
# Image, 1422 done
# Image, 1423 done
# Image, 1424 done
# Image, 1425 done
# Image, 1426 done
# Image, 1427 done
# Image, 1428 done
# Image, 1429 done
# Image, 1430 done
# Image, 1431 done
# Image, 1432 done
# Image, 1433 done
# Image, 1434 done
# Image, 1435 done
# Image, 1436 done
# Image, 1437 done
# Image, 1438 done
# Image, 1439 done
# Image, 1440 done
# Image, 1441 done
# Image, 1442 done
# Image, 1443 done
# Image, 1444 done
# Image, 1445 done
# Image, 1446 done
# Image, 1447 done
# Image, 1448 done
# Image, 1449 done
# Image, 1450 done
# Image, 1451 done
# Image, 1452 done
# Image, 1453 done
# Image, 1454 done
# Image, 1455 done
# Image, 1456 done
# Image, 1457 done
# Image, 1458 done
# Image, 1459 done
# Image, 1460 done
# Image, 1461 done
# Image, 1462 done
# Image, 1463 done
# Image, 1464 done
# Image, 1465 done
# Image, 1466 done
# Image, 1467 done
# Image, 1468 done
# Image, 1469 done
# Image, 1470 done
# Image, 1471 done
# Image, 1472 done
# Image, 1473 done
# Image, 1474 done
# Image, 1475 done
# Image, 1476 done
# Image, 1477 done
# Image, 1478 done
# Image, 1479 done
# Image, 1480 done
# Image, 1481 done
# Image, 1482 done
# Image, 1483 done
# Image, 1484 done
# Image, 1485 done
# Image, 1486 done
# Image, 1487 done
# Image, 1488 done
# Image, 1489 done
# Image, 1490 done
# Image, 1491 done
# Image, 1492 done
# Image, 1493 done
# Image, 1494 done
# Image, 1495 done
# Image, 1496 done
# Image, 1497 done
# Image, 1498 done
# Image, 1499 done
# Image, 1500 done
# Image, 1501 done
# Image, 1502 done
# Image, 1503 done
# Image, 1504 done
# Image, 1505 done
# Image, 1506 done
# Image, 1507 done
# Image, 1508 done
# Image, 1509 done
# Image, 1510 done
# Image, 1511 done
# Image, 1512 done
# Image, 1513 done
# Image, 1514 done
# Image, 1515 done
# Image, 1516 done
# Image, 1517 done
# Image, 1518 done
# Image, 1519 done
# Image, 1520 done
# Image, 1521 done
# Image, 1522 done
# Image, 1523 done
# Image, 1524 done
# Image, 1525 done
# Image, 1526 done
# Image, 1527 done
# Image, 1528 done
# Image, 1529 done
# Image, 1530 done
# Image, 1531 done
# Image, 1532 done
# Image, 1533 done
# Image, 1534 done
# Image, 1535 done
# Image, 1536 done
# Image, 1537 done
# Image, 1538 done
# Image, 1539 done
# Image, 1540 done
# Image, 1541 done
# Image, 1542 done
# Image, 1543 done
# Image, 1544 done
# Image, 1545 done
# Image, 1546 done
# Image, 1547 done
# Image, 1548 done
# Image, 1549 done
# Image, 1550 done
# Image, 1551 done
# Image, 1552 done
# Image, 1553 done
# Image, 1554 done
# Image, 1555 done
# Image, 1556 done
# Image, 1557 done
# Image, 1558 done
# Image, 1559 done
# Image, 1560 done
# Image, 1561 done
# Image, 1562 done
# Image, 1563 done
# Image, 1564 done
# Image, 1565 done
# Image, 1566 done
# Image, 1567 done
# Image, 1568 done
# Image, 1569 done
# Image, 1570 done
# Image, 1571 done
# Image, 1572 done
# Image, 1573 done
# Image, 1574 done
# Image, 1575 done
# Image, 1576 done
# Image, 1577 done
# Image, 1578 done
# Image, 1579 done
# Image, 1580 done
# Image, 1581 done
# Image, 1582 done
# Image, 1583 done
# Image, 1584 done
# Image, 1585 done
# Image, 1586 done
# Image, 1587 done
# Image, 1588 done
# Image, 1589 done
# Image, 1590 done
# Image, 1591 done
# Image, 1592 done
# Image, 1593 done
# Image, 1594 done
# Image, 1595 done
# Image, 1596 done
# Image, 1597 done
# Image, 1598 done
# Image, 1599 done
# Image, 1600 done
# Image, 1601 done
# Image, 1602 done
# Image, 1603 done
# Image, 1604 done
# Image, 1605 done
# Image, 1606 done
# Image, 1607 done
# Image, 1608 done
# Image, 1609 done
# Image, 1610 done
# Image, 1611 done
# Image, 1612 done
# Image, 1613 done
# Image, 1614 done
# Image, 1615 done
# Image, 1616 done
# Image, 1617 done
# Image, 1618 done
# Image, 1619 done
# Image, 1620 done
# Image, 1621 done
# Image, 1622 done
# Image, 1623 done
# Image, 1624 done
# Image, 1625 done
# Image, 1626 done
# Image, 1627 done
# Image, 1628 done
# Image, 1629 done
# Image, 1630 done
# Image, 1631 done
# Image, 1632 done
# Image, 1633 done
# Image, 1634 done
# Image, 1635 done
# Image, 1636 done
# Image, 1637 done
# Image, 1638 done
# Image, 1639 done
# Image, 1640 done
# Image, 1641 done
# Image, 1642 done
# Image, 1643 done
# Image, 1644 done
# Image, 1645 done
# Image, 1646 done
# Image, 1647 done
# Image, 1648 done
# Image, 1649 done
# Image, 1650 done
# Image, 1651 done
# Image, 1652 done
# Image, 1653 done
# Image, 1654 done
# Image, 1655 done
# Image, 1656 done
# Image, 1657 done
# Image, 1658 done
# Image, 1659 done
# Image, 1660 done
# Image, 1661 done
# Image, 1662 done
# Image, 1663 done
# Image, 1664 done
# Image, 1665 done
# Image, 1666 done
# Image, 1667 done
# Image, 1668 done
# Image, 1669 done
# Image, 1670 done
# Image, 1671 done
# Image, 1672 done
# Image, 1673 done
# Image, 1674 done
# Image, 1675 done
# Image, 1676 done
# Image, 1677 done
# Image, 1678 done
# Image, 1679 done
# Image, 1680 done
# Image, 1681 done
# Image, 1682 done
# Image, 1683 done
# Image, 1684 done
# Image, 1685 done
# Image, 1686 done
# Image, 1687 done
# Image, 1688 done
# Image, 1689 done
# Image, 1690 done
# Image, 1691 done
# Image, 1692 done
# Image, 1693 done
# Image, 1694 done
# Image, 1695 done
# Image, 1696 done
# Image, 1697 done
# Image, 1698 done
# Image, 1699 done
# Image, 1700 done
# Image, 1701 done
# Image, 1702 done
# Image, 1703 done
# Image, 1704 done
# Image, 1705 done
# Image, 1706 done
# Image, 1707 done
# Image, 1708 done
# Image, 1709 done
# Image, 1710 done
# Image, 1711 done
# Image, 1712 done
# Image, 1713 done
# Image, 1714 done
# Image, 1715 done
# Image, 1716 done
# Image, 1717 done
# Image, 1718 done
# Image, 1719 done
# Image, 1720 done
# Image, 1721 done
# Image, 1722 done
# Image, 1723 done
# Image, 1724 done
# Image, 1725 done
# Image, 1726 done
# Image, 1727 done
# Image, 1728 done
# Image, 1729 done
# Image, 1730 done
# Image, 1731 done
# Image, 1732 done
# Image, 1733 done
# Image, 1734 done
# Image, 1735 done
# Image, 1736 done
# Image, 1737 done
# Image, 1738 done
# Image, 1739 done
# Image, 1740 done
# Image, 1741 done
# Image, 1742 done
# Image, 1743 done
# Image, 1744 done
# Image, 1745 done
# Image, 1746 done
# Image, 1747 done
# Image, 1748 done
# Image, 1749 done
# Image, 1750 done
# Image, 1751 done
# Image, 1752 done
# Image, 1753 done
# Image, 1754 done
# Image, 1755 done
# Image, 1756 done
# Image, 1757 done
# Image, 1758 done
# Image, 1759 done
# Image, 1760 done
# Image, 1761 done
# Image, 1762 done
# Image, 1763 done
# Image, 1764 done
# Image, 1765 done
# Image, 1766 done
# Image, 1767 done
# Image, 1768 done
# Image, 1769 done
# Image, 1770 done
# Image, 1771 done
# Image, 1772 done
# Image, 1773 done
# Image, 1774 done
# Image, 1775 done
# Image, 1776 done
# Image, 1777 done
# Image, 1778 done
# Image, 1779 done
# Image, 1780 done
# Image, 1781 done
# Image, 1782 done
# Image, 1783 done
# Image, 1784 done
# Image, 1785 done
# Image, 1786 done
# Image, 1787 done
# Image, 1788 done
# Image, 1789 done
# Image, 1790 done
# Image, 1791 done
# Image, 1792 done
# Image, 1793 done
# Image, 1794 done
# Image, 1795 done
# Image, 1796 done
# Image, 1797 done
# Image, 1798 done
# Image, 1799 done
# Image, 1800 done
# Image, 1801 done
# Image, 1802 done
# Image, 1803 done
# Image, 1804 done
# Image, 1805 done
# Image, 1806 done
# Image, 1807 done
# Image, 1808 done
# Image, 1809 done
# Image, 1810 done
# Image, 1811 done
# Image, 1812 done
# Image, 1813 done
# Image, 1814 done
# Image, 1815 done
# Image, 1816 done
# Image, 1817 done
# Image, 1818 done
# Image, 1819 done
# Image, 1820 done
# Image, 1821 done
# Image, 1822 done
# Image, 1823 done
# Image, 1824 done
# Image, 1825 done
# Image, 1826 done
# Image, 1827 done
# Image, 1828 done
# Image, 1829 done
# Image, 1830 done
# Image, 1831 done
# Image, 1832 done
# Image, 1833 done
# Image, 1834 done
# Image, 1835 done
# Image, 1836 done
# Image, 1837 done
# Image, 1838 done
# Image, 1839 done
# Image, 1840 done
# Image, 1841 done
# Image, 1842 done
# Image, 1843 done
# Image, 1844 done
# Image, 1845 done
# Image, 1846 done
# Image, 1847 done
# Image, 1848 done
# Image, 1849 done
# Image, 1850 done
# Image, 1851 done
# Image, 1852 done
# Image, 1853 done
# Image, 1854 done
# Image, 1855 done
# Image, 1856 done
# Image, 1857 done
# Image, 1858 done
# Image, 1859 done
# Image, 1860 done
# Image, 1861 done
# Image, 1862 done
# Image, 1863 done
# Image, 1864 done
# Image, 1865 done
# Image, 1866 done
# Image, 1867 done
# Image, 1868 done
# Image, 1869 done
# Image, 1870 done
# Image, 1871 done
# Image, 1872 done
# Image, 1873 done
# Image, 1874 done
# Image, 1875 done
# Image, 1876 done
# Image, 1877 done
# Image, 1878 done
# Image, 1879 done
# Image, 1880 done
# Image, 1881 done
# Image, 1882 done
# Image, 1883 done
# Image, 1884 done
# Image, 1885 done
# Image, 1886 done
# Image, 1887 done
# Image, 1888 done
# Image, 1889 done
# Image, 1890 done
# Image, 1891 done
# Image, 1892 done
# Image, 1893 done
# Image, 1894 done
# Image, 1895 done
# Image, 1896 done
# Image, 1897 done
# Image, 1898 done
# Image, 1899 done
# Image, 1900 done
# Image, 1901 done
# Image, 1902 done
# Image, 1903 done
# Image, 1904 done
# Image, 1905 done
# Image, 1906 done
# Image, 1907 done
# Image, 1908 done
# Image, 1909 done
# Image, 1910 done
# Image, 1911 done
# Image, 1912 done
# Image, 1913 done
# Image, 1914 done
# Image, 1915 done
# Image, 1916 done
# Image, 1917 done
# Image, 1918 done
# Image, 1919 done
# Image, 1920 done
# Image, 1921 done
# Image, 1922 done
# Image, 1923 done
# Image, 1924 done
# Image, 1925 done
# Image, 1926 done
# Image, 1927 done
# Image, 1928 done
# Image, 1929 done
# Image, 1930 done
# Image, 1931 done
# Image, 1932 done
# Image, 1933 done
# Image, 1934 done
# Image, 1935 done
# Image, 1936 done
# Image, 1937 done
# Image, 1938 done
# Image, 1939 done
# Image, 1940 done
# Image, 1941 done
# Image, 1942 done
# Image, 1943 done
# Image, 1944 done
# Image, 1945 done
# Image, 1946 done
# Image, 1947 done
# Image, 1948 done
# Image, 1949 done
# Image, 1950 done
# Image, 1951 done
# Image, 1952 done
# Image, 1953 done
# Image, 1954 done
# Image, 1955 done
# Image, 1956 done
# Image, 1957 done
# Image, 1958 done
# Image, 1959 done
# Image, 1960 done
# Image, 1961 done
# Image, 1962 done
# Image, 1963 done
# Image, 1964 done
# Image, 1965 done
# Image, 1966 done
# Image, 1967 done
# Image, 1968 done
# Image, 1969 done
# Image, 1970 done
# Image, 1971 done
# Image, 1972 done
# Image, 1973 done
# Image, 1974 done
# Image, 1975 done
# Image, 1976 done
# Image, 1977 done
# Image, 1978 done
# Image, 1979 done
# Image, 1980 done
# Image, 1981 done
# Image, 1982 done
# Image, 1983 done
# Image, 1984 done
# Image, 1985 done
# Image, 1986 done
# Image, 1987 done
# Image, 1988 done
# Image, 1989 done
# Image, 1990 done
# Image, 1991 done
# Image, 1992 done
# Image, 1993 done
# Image, 1994 done
# Image, 1995 done
# Image, 1996 done
# Image, 1997 done
# Image, 1998 done
# Image, 1999 done
# Image, 2000 done
# Image, 2001 done
# Image, 2002 done
# Image, 2003 done
# Image, 2004 done
# Image, 2005 done
# Image, 2006 done
# Image, 2007 done
# Image, 2008 done
# Image, 2009 done
# Image, 2010 done
# Image, 2011 done
# Image, 2012 done
# Image, 2013 done
# Image, 2014 done
# Image, 2015 done
# Image, 2016 done
# Image, 2017 done
# Image, 2018 done
# Image, 2019 done
# Image, 2020 done
# Image, 2021 done
# Image, 2022 done
# Image, 2023 done
# Image, 2024 done
# Image, 2025 done
# Image, 2026 done
# Image, 2027 done
# Image, 2028 done
# Image, 2029 done
# Image, 2030 done
# Image, 2031 done
# Image, 2032 done
# Image, 2033 done
# Image, 2034 done
# Image, 2035 done
# Image, 2036 done
# Image, 2037 done
# Image, 2038 done
# Image, 2039 done
# Image, 2040 done
# Image, 2041 done
# Image, 2042 done
# Image, 2043 done
# Image, 2044 done
# Image, 2045 done
# Image, 2046 done
# Image, 2047 done
# Image, 2048 done
# Image, 2049 done
# Image, 2050 done
# Image, 2051 done
# Image, 2052 done
# Image, 2053 done
# Image, 2054 done
# Image, 2055 done
# Image, 2056 done
# Image, 2057 done
# Image, 2058 done
# Image, 2059 done
# Image, 2060 done
# Image, 2061 done
# Image, 2062 done
# Image, 2063 done
# Image, 2064 done
# Image, 2065 done
# Image, 2066 done
# Image, 2067 done
# Image, 2068 done
# Image, 2069 done
# Image, 2070 done
# Image, 2071 done
# Image, 2072 done
# Image, 2073 done
# Image, 2074 done
# Image, 2075 done
# Image, 2076 done
# Image, 2077 done
# Image, 2078 done
# Image, 2079 done
# Image, 2080 done
# Image, 2081 done
# Image, 2082 done
# Image, 2083 done
# Image, 2084 done
# Image, 2085 done
# Image, 2086 done
# Image, 2087 done
# Image, 2088 done
# Image, 2089 done
# Image, 2090 done
# Image, 2091 done
# Image, 2092 done
# Image, 2093 done
# Image, 2094 done
# Image, 2095 done
# Image, 2096 done
# Image, 2097 done
# Image, 2098 done
# Image, 2099 done
# Image, 2100 done
# Image, 2101 done
# Image, 2102 done
# Image, 2103 done
# Image, 2104 done
# Image, 2105 done
# Image, 2106 done
# Image, 2107 done
# Image, 2108 done
# Image, 2109 done
# Image, 2110 done
# Image, 2111 done
# Image, 2112 done
# Image, 2113 done
# Image, 2114 done
# Image, 2115 done
# Image, 2116 done
# Image, 2117 done
# Image, 2118 done
# Image, 2119 done
# Image, 2120 done
# Image, 2121 done
# Image, 2122 done
# Image, 2123 done
# Image, 2124 done
# Image, 2125 done
# Image, 2126 done
# Image, 2127 done
# Image, 2128 done
# Image, 2129 done
# Image, 2130 done
# Image, 2131 done
# Image, 2132 done
# Image, 2133 done
# Image, 2134 done
# Image, 2135 done
# Image, 2136 done
# Image, 2137 done
# Image, 2138 done
# Image, 2139 done
# Image, 2140 done
# Image, 2141 done
# Image, 2142 done
# Image, 2143 done
# Image, 2144 done
# Image, 2145 done
# Image, 2146 done
# Image, 2147 done
# Image, 2148 done
# Image, 2149 done
# Image, 2150 done
# Image, 2151 done
# Image, 2152 done
# Image, 2153 done
# Image, 2154 done
# Image, 2155 done
# Image, 2156 done
# Image, 2157 done
# Image, 2158 done
# Image, 2159 done
# Image, 2160 done
# Image, 2161 done
# Image, 2162 done
# Image, 2163 done
# Image, 2164 done
# Image, 2165 done
# Image, 2166 done
# Image, 2167 done
# Image, 2168 done
# Image, 2169 done
# Image, 2170 done
# Image, 2171 done
# Image, 2172 done
# Image, 2173 done
# Image, 2174 done
# Image, 2175 done
# Image, 2176 done
# Image, 2177 done
# Image, 2178 done
# Image, 2179 done
# Image, 2180 done
# Image, 2181 done
# Image, 2182 done
# Image, 2183 done
# Image, 2184 done
# Image, 2185 done
# Image, 2186 done
# Image, 2187 done
# Image, 2188 done
# Image, 2189 done
# Image, 2190 done
# Image, 2191 done
# Image, 2192 done
# Image, 2193 done
# Image, 2194 done
# Image, 2195 done
# Image, 2196 done
# Image, 2197 done
# Image, 2198 done
# Image, 2199 done
# Image, 2200 done
# Image, 2201 done
# Image, 2202 done
# Image, 2203 done
# Image, 2204 done
# Image, 2205 done
# Image, 2206 done
# Image, 2207 done
# Image, 2208 done
# Image, 2209 done
# Image, 2210 done
# Image, 2211 done
# Image, 2212 done
# Image, 2213 done
# Image, 2214 done
# Image, 2215 done
# Image, 2216 done
# Image, 2217 done
# Image, 2218 done
# Image, 2219 done
# Image, 2220 done
# Image, 2221 done
# Image, 2222 done
# Image, 2223 done
# Image, 2224 done
# Image, 2225 done
# Image, 2226 done
# Image, 2227 done
# Image, 2228 done
# Image, 2229 done
# Image, 2230 done
# Image, 2231 done
# Image, 2232 done
# Image, 2233 done
# Image, 2234 done
# Image, 2235 done
# Image, 2236 done
# Image, 2237 done
# Image, 2238 done
# Image, 2239 done
# Image, 2240 done
# Image, 2241 done
# Image, 2242 done
# Image, 2243 done
# Image, 2244 done
# Image, 2245 done
# Image, 2246 done
# Image, 2247 done
# Image, 2248 done
# Image, 2249 done
# Image, 2250 done
# Image, 2251 done
# Image, 2252 done
# Image, 2253 done
# Image, 2254 done
# Image, 2255 done
# Image, 2256 done
# Image, 2257 done
# Image, 2258 done
# Image, 2259 done
# Image, 2260 done
# Image, 2261 done
# Image, 2262 done
# Image, 2263 done
# Image, 2264 done
# Image, 2265 done
# Image, 2266 done
# Image, 2267 done
# Image, 2268 done
# Image, 2269 done
# Image, 2270 done
# Image, 2271 done
# Image, 2272 done
# Image, 2273 done
# Image, 2274 done
# Image, 2275 done
# Image, 2276 done
# Image, 2277 done
# Image, 2278 done
# Image, 2279 done
# Image, 2280 done
# Image, 2281 done
# Image, 2282 done
# Image, 2283 done
# Image, 2284 done
# Image, 2285 done
# Image, 2286 done
# Image, 2287 done
# Image, 2288 done
# Image, 2289 done
# Image, 2290 done
# Image, 2291 done
# Image, 2292 done
# Image, 2293 done
# Image, 2294 done
# Image, 2295 done
# Image, 2296 done
# Image, 2297 done
# Image, 2298 done
# Image, 2299 done
# Image, 2300 done
# Image, 2301 done
# Image, 2302 done
# Image, 2303 done
# Image, 2304 done
# Image, 2305 done
# Image, 2306 done
# Image, 2307 done
# Image, 2308 done
# Image, 2309 done
# Image, 2310 done
# Image, 2311 done
# Image, 2312 done
# Image, 2313 done
# Image, 2314 done
# Image, 2315 done
# Image, 2316 done
# Image, 2317 done
# Image, 2318 done
# Image, 2319 done
# Image, 2320 done
# Image, 2321 done
# Image, 2322 done
# Image, 2323 done
# Image, 2324 done
# Image, 2325 done
# Image, 2326 done
# Image, 2327 done
# Image, 2328 done
# Image, 2329 done
# Image, 2330 done
# Image, 2331 done
# Image, 2332 done
# Image, 2333 done
# Image, 2334 done
# Image, 2335 done
# Image, 2336 done
# Image, 2337 done
# Image, 2338 done
# Image, 2339 done
# Image, 2340 done
# Image, 2341 done
# Image, 2342 done
# Image, 2343 done
# Image, 2344 done
# Image, 2345 done
# Image, 2346 done
# Image, 2347 done
# Image, 2348 done
# Image, 2349 done
# Image, 2350 done
# Image, 2351 done
# Image, 2352 done
# Image, 2353 done
# Image, 2354 done
# Image, 2355 done
# Image, 2356 done
# Image, 2357 done
# Image, 2358 done
# Image, 2359 done
# Image, 2360 done
# Image, 2361 done
# Image, 2362 done
# Image, 2363 done
# Image, 2364 done
# Image, 2365 done
# Image, 2366 done
# Image, 2367 done
# Image, 2368 done
# Image, 2369 done
# Image, 2370 done
# Image, 2371 done
# Image, 2372 done
# Image, 2373 done
# Image, 2374 done
# Image, 2375 done
# Image, 2376 done
# Image, 2377 done
# Image, 2378 done
# Image, 2379 done
# Image, 2380 done
# Image, 2381 done
# Image, 2382 done
# Image, 2383 done
# Image, 2384 done
# Image, 2385 done
# Image, 2386 done
# Image, 2387 done
# Image, 2388 done
# Image, 2389 done
# Image, 2390 done
# Image, 2391 done
# Image, 2392 done
# Image, 2393 done
# Image, 2394 done
# Image, 2395 done
# Image, 2396 done
# Image, 2397 done
# Image, 2398 done
# Image, 2399 done
# Image, 2400 done
# Image, 2401 done
# Image, 2402 done
# Image, 2403 done
# Image, 2404 done
# Image, 2405 done
# Image, 2406 done
# Image, 2407 done
# Image, 2408 done
# Image, 2409 done
# Image, 2410 done
# Image, 2411 done
# Image, 2412 done
# Image, 2413 done
# Image, 2414 done
# Image, 2415 done
# Image, 2416 done
# Image, 2417 done
# Image, 2418 done
# Image, 2419 done
# Image, 2420 done
# Image, 2421 done
# Image, 2422 done
# Image, 2423 done
# Image, 2424 done
# Image, 2425 done
# Image, 2426 done
# Image, 2427 done
# Image, 2428 done
# Image, 2429 done
# Image, 2430 done
# Image, 2431 done
# Image, 2432 done
# Image, 2433 done
# Image, 2434 done
# Image, 2435 done
# Image, 2436 done
# Image, 2437 done
# Image, 2438 done
# Image, 2439 done
# Image, 2440 done
# Image, 2441 done
# Image, 2442 done
# Image, 2443 done
# Image, 2444 done
# Image, 2445 done
# Image, 2446 done
# Image, 2447 done
# Image, 2448 done
# Image, 2449 done
# Image, 2450 done
# Image, 2451 done
# Image, 2452 done
# Image, 2453 done
# Image, 2454 done
# Image, 2455 done
# Image, 2456 done
# Image, 2457 done
# Image, 2458 done
# Image, 2459 done
# Image, 2460 done
# Image, 2461 done
# Image, 2462 done
# Image, 2463 done
# Image, 2464 done
# Image, 2465 done
# Image, 2466 done
# Image, 2467 done
# Image, 2468 done
# Image, 2469 done
# Image, 2470 done
# Image, 2471 done
# Image, 2472 done
# Image, 2473 done
# Image, 2474 done
# Image, 2475 done
# Image, 2476 done
# Image, 2477 done
# Image, 2478 done
# Image, 2479 done
# Image, 2480 done
# Image, 2481 done
# Image, 2482 done
# Image, 2483 done
# Image, 2484 done
# Image, 2485 done
# Image, 2486 done
# Image, 2487 done
# Image, 2488 done
# Image, 2489 done
# Image, 2490 done
# Image, 2491 done
# Image, 2492 done
# Image, 2493 done
# Image, 2494 done
# Image, 2495 done
# Image, 2496 done
# Image, 2497 done
# Image, 2498 done
# Image, 2499 done
# Image, 2500 done
# Image, 2501 done
# Image, 2502 done
# Image, 2503 done
# Image, 2504 done
# Image, 2505 done
# Image, 2506 done
# Image, 2507 done
# Image, 2508 done
# Image, 2509 done
# Image, 2510 done
# Image, 2511 done
# Image, 2512 done
# Image, 2513 done
# Image, 2514 done
# Image, 2515 done
# Image, 2516 done
# Image, 2517 done
# Image, 2518 done
# Image, 2519 done
# Image, 2520 done
# Image, 2521 done
# Image, 2522 done
# Image, 2523 done
# Image, 2524 done
# Image, 2525 done
# Image, 2526 done
# Image, 2527 done
# Image, 2528 done
# Image, 2529 done
# Image, 2530 done
# Image, 2531 done
# Image, 2532 done
# Image, 2533 done
# Image, 2534 done
# Image, 2535 done
# Image, 2536 done
# Image, 2537 done
# Image, 2538 done
# Image, 2539 done
# Image, 2540 done
# Image, 2541 done
# Image, 2542 done
# Image, 2543 done
# Image, 2544 done
# Image, 2545 done
# Image, 2546 done
# Image, 2547 done
# Image, 2548 done
# Image, 2549 done
# Image, 2550 done
# Image, 2551 done
# Image, 2552 done
# Image, 2553 done
# Image, 2554 done
# Image, 2555 done
# Image, 2556 done
# Image, 2557 done
# Image, 2558 done
# Image, 2559 done
# Image, 2560 done
# Image, 2561 done
# Image, 2562 done
# Image, 2563 done
# Image, 2564 done
# Image, 2565 done
# Image, 2566 done
# Image, 2567 done
# Image, 2568 done
# Image, 2569 done
# Image, 2570 done
# Image, 2571 done
# Image, 2572 done
# Image, 2573 done
# Image, 2574 done
# Image, 2575 done
# Image, 2576 done
# Image, 2577 done
# Image, 2578 done
# Image, 2579 done
# Image, 2580 done
# Image, 2581 done
# Image, 2582 done
# Image, 2583 done
# Image, 2584 done
# Image, 2585 done
# Image, 2586 done
# Image, 2587 done
# Image, 2588 done
# Image, 2589 done
# Image, 2590 done
# Image, 2591 done
# Image, 2592 done
# Image, 2593 done
# Image, 2594 done
# Image, 2595 done
# Image, 2596 done
# Image, 2597 done
# Image, 2598 done
# Image, 2599 done
# Image, 2600 done
# Image, 2601 done
# Image, 2602 done
# Image, 2603 done
# Image, 2604 done
# Image, 2605 done
# Image, 2606 done
# Image, 2607 done
# Image, 2608 done
# Image, 2609 done
# Image, 2610 done
# Image, 2611 done
# Image, 2612 done
# Image, 2613 done
# Image, 2614 done
# Image, 2615 done
# Image, 2616 done
# Image, 2617 done
# Image, 2618 done
# Image, 2619 done
# Image, 2620 done
# Image, 2621 done
# Image, 2622 done
# Image, 2623 done
# Image, 2624 done
# Image, 2625 done
# Image, 2626 done
# Image, 2627 done
# Image, 2628 done
# Image, 2629 done
# Image, 2630 done
# Image, 2631 done
# Image, 2632 done
# Image, 2633 done
# Image, 2634 done
# Image, 2635 done
# Image, 2636 done
# Image, 2637 done
# Image, 2638 done
# Image, 2639 done
# Image, 2640 done
# Image, 2641 done
# Image, 2642 done
# Image, 2643 done
# Image, 2644 done
# Image, 2645 done
# Image, 2646 done
# Image, 2647 done
# Image, 2648 done
# Image, 2649 done
# Image, 2650 done
# Image, 2651 done
# Image, 2652 done
# Image, 2653 done
# Image, 2654 done
# Image, 2655 done
# Image, 2656 done
# Image, 2657 done
# Image, 2658 done
# Image, 2659 done
# Image, 2660 done
# Image, 2661 done
# Image, 2662 done
# Image, 2663 done
# Image, 2664 done
# Image, 2665 done
# Image, 2666 done
# Image, 2667 done
# Image, 2668 done
# Image, 2669 done
# Image, 2670 done
# Image, 2671 done
# Image, 2672 done
# Image, 2673 done
# Image, 2674 done
# Image, 2675 done
# Image, 2676 done
# Image, 2677 done
# Image, 2678 done
# Image, 2679 done
# Image, 2680 done
# Image, 2681 done
# Image, 2682 done
# Image, 2683 done
# Image, 2684 done
# Image, 2685 done
# Image, 2686 done
# Image, 2687 done
# Image, 2688 done
# Image, 2689 done
# Image, 2690 done
# Image, 2691 done
# Image, 2692 done
# Image, 2693 done
# Image, 2694 done
# Image, 2695 done
# Image, 2696 done
# Image, 2697 done
# Image, 2698 done
# Image, 2699 done
# Image, 2700 done
# Image, 2701 done
# Image, 2702 done
# Image, 2703 done
# Image, 2704 done
# Image, 2705 done
# Image, 2706 done
# Image, 2707 done
# Image, 2708 done
# Image, 2709 done
# Image, 2710 done
# Image, 2711 done
# Image, 2712 done
# Image, 2713 done
# Image, 2714 done
# Image, 2715 done
# Image, 2716 done
# Image, 2717 done
# Image, 2718 done
# Image, 2719 done
# Image, 2720 done
# Image, 2721 done
# Image, 2722 done
# Image, 2723 done
# Image, 2724 done
# Image, 2725 done
# Image, 2726 done
# Image, 2727 done
# Image, 2728 done
# Image, 2729 done
# Image, 2730 done
# Image, 2731 done
# Image, 2732 done
# Image, 2733 done
# Image, 2734 done
# Image, 2735 done
# Image, 2736 done
# Image, 2737 done
# Image, 2738 done
# Image, 2739 done
# Image, 2740 done
# Image, 2741 done
# Image, 2742 done
# Image, 2743 done
# Image, 2744 done
# Image, 2745 done
# Image, 2746 done
# Image, 2747 done
# Image, 2748 done
# Image, 2749 done
# Image, 2750 done
# Image, 2751 done
# Image, 2752 done
# Image, 2753 done
# Image, 2754 done
# Image, 2755 done
# Image, 2756 done
# Image, 2757 done
# Image, 2758 done
# Image, 2759 done
# Image, 2760 done
# Image, 2761 done
# Image, 2762 done
# Image, 2763 done
# Image, 2764 done
# Image, 2765 done
# Image, 2766 done
# Image, 2767 done
# Image, 2768 done
# Image, 2769 done
# Image, 2770 done
# Image, 2771 done
# Image, 2772 done
# Image, 2773 done
# Image, 2774 done
# Image, 2775 done
# Image, 2776 done
# Image, 2777 done
# Image, 2778 done
# Image, 2779 done
# Image, 2780 done
# Image, 2781 done
# Image, 2782 done
# Image, 2783 done
# Image, 2784 done
# Image, 2785 done
# Image, 2786 done
# Image, 2787 done
# Image, 2788 done
# Image, 2789 done
# Image, 2790 done
# Image, 2791 done
# Image, 2792 done
# Image, 2793 done
# Image, 2794 done
# Image, 2795 done
# Image, 2796 done
# Image, 2797 done
# Image, 2798 done
# Image, 2799 done
# Image, 2800 done
# Image, 2801 done
# Image, 2802 done
# Image, 2803 done
# Image, 2804 done
# Image, 2805 done
# Image, 2806 done
# Image, 2807 done
# Image, 2808 done
# Image, 2809 done
# Image, 2810 done
# Image, 2811 done
# Image, 2812 done
# Image, 2813 done
# Image, 2814 done
# Image, 2815 done
# Image, 2816 done
# Image, 2817 done
# Image, 2818 done
# Image, 2819 done
# Image, 2820 done
# Image, 2821 done
# Image, 2822 done
# Image, 2823 done
# Image, 2824 done
# Image, 2825 done
# Image, 2826 done
# Image, 2827 done
# Image, 2828 done
# Image, 2829 done
# Image, 2830 done
# Image, 2831 done
# Image, 2832 done
# Image, 2833 done
# Image, 2834 done
# Image, 2835 done
# Image, 2836 done
# Image, 2837 done
# Image, 2838 done
# Image, 2839 done
# Image, 2840 done
# Image, 2841 done
# Image, 2842 done
# Image, 2843 done
# Image, 2844 done
# Image, 2845 done
# Image, 2846 done
# Image, 2847 done
# Image, 2848 done
# Image, 2849 done
# Image, 2850 done
# Image, 2851 done
# Image, 2852 done
# Image, 2853 done
# Image, 2854 done
# Image, 2855 done
# Image, 2856 done
# Image, 2857 done
# Image, 2858 done
# Image, 2859 done
# Image, 2860 done
# Image, 2861 done
# Image, 2862 done
# Image, 2863 done
# Image, 2864 done
# Image, 2865 done
# Image, 2866 done
# Image, 2867 done
# Image, 2868 done
# Image, 2869 done
# Image, 2870 done
# Image, 2871 done
# Image, 2872 done
# Image, 2873 done
# Image, 2874 done
# Image, 2875 done
# Image, 2876 done
# Image, 2877 done
# Image, 2878 done
# Image, 2879 done
# Image, 2880 done
# Image, 2881 done
# Image, 2882 done
# Image, 2883 done
# Image, 2884 done
# Image, 2885 done
# Image, 2886 done
# Image, 2887 done
# ...
# Image, 4602 done
# Image, 4603 done
# Image, 4604 done
# Image, 4605 done
# Image, 4606 done
# Image, 4607 done
# Image, 4608 done
# Image, 4609 done
# Image, 4610 done
# Image, 4611 done
# Image, 4612 done
# Image, 4613 done
# Image, 4614 done
# Image, 4615 done
# Image, 4616 done
# Image, 4617 done
# Image, 4618 done
# Image, 4619 done
# Image, 4620 done
# Image, 4621 done
# Image, 4622 done
# Image, 4623 done
# Image, 4624 done
# Image, 4625 done
# Image, 4626 done
# Image, 4627 done
# Image, 4628 done
# Image, 4629 done
# Image, 4630 done
# Image, 4631 done
# Image, 4632 done
# Image, 4633 done
# Image, 4634 done
# Image, 4635 done
# Image, 4636 done
# Image, 4637 done
# Image, 4638 done
# Image, 4639 done
# Image, 4640 done
# Image, 4641 done
# Image, 4642 done
# Image, 4643 done
# Image, 4644 done
# Image, 4645 done
# Image, 4646 done
# Image, 4647 done
# Image, 4648 done
# Image, 4649 done
# Image, 4650 done
# Image, 4651 done
# Image, 4652 done
# Image, 4653 done
# Image, 4654 done
# Image, 4655 done
# Image, 4656 done
# Image, 4657 done
# Image, 4658 done
# Image, 4659 done
# Image, 4660 done
# Image, 4661 done
# Image, 4662 done
# Image, 4663 done
# Image, 4664 done
# Image, 4665 done
# Image, 4666 done
# Image, 4667 done
# Image, 4668 done
# Image, 4669 done
# Image, 4670 done
# Image, 4671 done
# Image, 4672 done
# Image, 4673 done
# Image, 4674 done
# Image, 4675 done
# Image, 4676 done
# Image, 4677 done
# Image, 4678 done
# Image, 4679 done
# Image, 4680 done
# Image, 4681 done
# Image, 4682 done
# Image, 4683 done
# Image, 4684 done
# Image, 4685 done
# Image, 4686 done
# Image, 4687 done
# Image, 4688 done
# Image, 4689 done
# Image, 4690 done
# Image, 4691 done
# Image, 4692 done
# Image, 4693 done
# Image, 4694 done
# Image, 4695 done
# Image, 4696 done
# Image, 4697 done
# Image, 4698 done
# Image, 4699 done
# Image, 4700 done
# Image, 4701 done
# Image, 4702 done
# Image, 4703 done
# Image, 4704 done
# Image, 4705 done
# Image, 4706 done
# Image, 4707 done
# Image, 4708 done
# Image, 4709 done
# Image, 4710 done
# Image, 4711 done
# Image, 4712 done
# Image, 4713 done
# Image, 4714 done
# Image, 4715 done
# Image, 4716 done
# Image, 4717 done
# Image, 4718 done
# Image, 4719 done
# Image, 4720 done
# Image, 4721 done
# Image, 4722 done
# Image, 4723 done
# Image, 4724 done
# Image, 4725 done
# Image, 4726 done
# Image, 4727 done
# Image, 4728 done
# Image, 4729 done
# Image, 4730 done
# Image, 4731 done
# Image, 4732 done
# Image, 4733 done
# Image, 4734 done
# Image, 4735 done
# Image, 4736 done
# Image, 4737 done
# Image, 4738 done
# Image, 4739 done
# Image, 4740 done
# Image, 4741 done
# Image, 4742 done
# Image, 4743 done
# Image, 4744 done
# Image, 4745 done
# Image, 4746 done
# Image, 4747 done
# Image, 4748 done
# Image, 4749 done
# Image, 4750 done
# Image, 4751 done
# Image, 4752 done
# Image, 4753 done
# Image, 4754 done
# Image, 4755 done
# Image, 4756 done
# Image, 4757 done
# Image, 4758 done
# Image, 4759 done
# Image, 4760 done
# Image, 4761 done
# Image, 4762 done
# Image, 4763 done
# Image, 4764 done
# Image, 4765 done
# Image, 4766 done
# Image, 4767 done
# Image, 4768 done
# Image, 4769 done
# Image, 4770 done
# Image, 4771 done
# Image, 4772 done
# Image, 4773 done
# Image, 4774 done
# Image, 4775 done
# Image, 4776 done
# Image, 4777 done
# Image, 4778 done
# Image, 4779 done
# Image, 4780 done
# Image, 4781 done
# Image, 4782 done
# Image, 4783 done
# Image, 4784 done
# Image, 4785 done
# Image, 4786 done
# Image, 4787 done
# Image, 4788 done
# Image, 4789 done
# Image, 4790 done
# Image, 4791 done
# Image, 4792 done
# Image, 4793 done
# Image, 4794 done
# Image, 4795 done
# Image, 4796 done
# Image, 4797 done
# Image, 4798 done
# Image, 4799 done
# Image, 4800 done
# Image, 4801 done
# Image, 4802 done
# Image, 4803 done
# Image, 4804 done
# Image, 4805 done
# Image, 4806 done
# Image, 4807 done
# Image, 4808 done
# Image, 4809 done
# Image, 4810 done
# Image, 4811 done
# Image, 4812 done
# Image, 4813 done
# Image, 4814 done
# Image, 4815 done
# Image, 4816 done
# Image, 4817 done
# Image, 4818 done
# Image, 4819 done
# Image, 4820 done
# Image, 4821 done
# Image, 4822 done
# Image, 4823 done
# Image, 4824 done
# Image, 4825 done
# Image, 4826 done
# Image, 4827 done
# Image, 4828 done
# Image, 4829 done
# Image, 4830 done
# Image, 4831 done
# Image, 4832 done
# Image, 4833 done
# Image, 4834 done
# Image, 4835 done
# Image, 4836 done
# Image, 4837 done
# Image, 4838 done
# Image, 4839 done
# Image, 4840 done
# Image, 4841 done
# Image, 4842 done
# Image, 4843 done
# Image, 4844 done
# Image, 4845 done
# Image, 4846 done
# Image, 4847 done
# Image, 4848 done
# Image, 4849 done
# Image, 4850 done
# Image, 4851 done
# Image, 4852 done
# Image, 4853 done
# Image, 4854 done
# Image, 4855 done
# Image, 4856 done
# Image, 4857 done
# Image, 4858 done
# Image, 4859 done
# Image, 4860 done
# Image, 4861 done
# Image, 4862 done
# Image, 4863 done
# Image, 4864 done
# Image, 4865 done
# Image, 4866 done
# Image, 4867 done
# Image, 4868 done
# Image, 4869 done
# Image, 4870 done
# Image, 4871 done
# Image, 4872 done
# Image, 4873 done
# Image, 4874 done
# Image, 4875 done
# Image, 4876 done
# Image, 4877 done
# Image, 4878 done
# Image, 4879 done
# Image, 4880 done
# Image, 4881 done
# Image, 4882 done
# Image, 4883 done
# Image, 4884 done
# Image, 4885 done
# Image, 4886 done
# Image, 4887 done
# Image, 4888 done
# Image, 4889 done
# Image, 4890 done
# Image, 4891 done
# Image, 4892 done
# Image, 4893 done
# Image, 4894 done
# Image, 4895 done
# Image, 4896 done
# Image, 4897 done
# Image, 4898 done
# Image, 4899 done
# Image, 4900 done
# Image, 4901 done
# Image, 4902 done
# Image, 4903 done
# Image, 4904 done
# Image, 4905 done
# Image, 4906 done
# Image, 4907 done
# Image, 4908 done
# Image, 4909 done
# Image, 4910 done
# Image, 4911 done
# Image, 4912 done
# Image, 4913 done
# Image, 4914 done
# Image, 4915 done
# Image, 4916 done
# Image, 4917 done
# Image, 4918 done
# Image, 4919 done
# Image, 4920 done
# Image, 4921 done
# Image, 4922 done
# Image, 4923 done
# Image, 4924 done
# Image, 4925 done
# Image, 4926 done
# Image, 4927 done
# Image, 4928 done
# Image, 4929 done
# Image, 4930 done
# Image, 4931 done
# Image, 4932 done
# Image, 4933 done
# Image, 4934 done
# Image, 4935 done
# Image, 4936 done
# Image, 4937 done
# Image, 4938 done
# Image, 4939 done
# Image, 4940 done
# Image, 4941 done
# Image, 4942 done
# Image, 4943 done
# Image, 4944 done
# Image, 4945 done
# Image, 4946 done
# Image, 4947 done
# Image, 4948 done
# Image, 4949 done
# Image, 4950 done
# Image, 4951 done
# Image, 4952 done
# Image, 4953 done
# Image, 4954 done
# Image, 4955 done
# Image, 4956 done
# Image, 4957 done
# Image, 4958 done
# Image, 4959 done
# Image, 4960 done
# Image, 4961 done
# Image, 4962 done
# Image, 4963 done
# Image, 4964 done
# Image, 4965 done
# Image, 4966 done
# Image, 4967 done
# Image, 4968 done
# Image, 4969 done
# Image, 4970 done
# Image, 4971 done
# Image, 4972 done
# Image, 4973 done
# Image, 4974 done
# Image, 4975 done
# Image, 4976 done
# Image, 4977 done
# Image, 4978 done
# Image, 4979 done
# Image, 4980 done
# Image, 4981 done
# Image, 4982 done
# Image, 4983 done
# Image, 4984 done
# Image, 4985 done
# Image, 4986 done
# Image, 4987 done
# Image, 4988 done
# Image, 4989 done
# Image, 4990 done
# Image, 4991 done
# Image, 4992 done
# Image, 4993 done
# Image, 4994 done
# Image, 4995 done
# Image, 4996 done
# Image, 4997 done
# Image, 4998 done
# Image, 4999 done
# Image, 5000 done
# Image, 5001 done
# Image, 5002 done
# Image, 5003 done
# Image, 5004 done
# Image, 5005 done
# Image, 5006 done
# Image, 5007 done
# Image, 5008 done
# Image, 5009 done
# Image, 5010 done
# Image, 5011 done
# Image, 5012 done
# Image, 5013 done
# Image, 5014 done
# Image, 5015 done
# Image, 5016 done
# Image, 5017 done
# Image, 5018 done
# Image, 5019 done
# Image, 5020 done
# Image, 5021 done
# Image, 5022 done
# Image, 5023 done
# Image, 5024 done
# Image, 5025 done
# Image, 5026 done
# Image, 5027 done
# Image, 5028 done
# Image, 5029 done
# Image, 5030 done
# Image, 5031 done
# Image, 5032 done
# Image, 5033 done
# Image, 5034 done
# Image, 5035 done
# Image, 5036 done
# Image, 5037 done
# Image, 5038 done
# Image, 5039 done
# Image, 5040 done
# Image, 5041 done
# Image, 5042 done
# Image, 5043 done
# Image, 5044 done
# Image, 5045 done
# Image, 5046 done
# Image, 5047 done
# Image, 5048 done
# Image, 5049 done
# Image, 5050 done
# Image, 5051 done
# Image, 5052 done
# Image, 5053 done
# Image, 5054 done
# Image, 5055 done
# Image, 5056 done
# Image, 5057 done
# Image, 5058 done
# Image, 5059 done
# Image, 5060 done
# Image, 5061 done
# Image, 5062 done
# Image, 5063 done
# Image, 5064 done
# Image, 5065 done
# Image, 5066 done
# Image, 5067 done
# Image, 5068 done
# Image, 5069 done
# Image, 5070 done
# Image, 5071 done
# Image, 5072 done
# Image, 5073 done
# Image, 5074 done
# Image, 5075 done
# Image, 5076 done
# Image, 5077 done
# Image, 5078 done
# Image, 5079 done
# Image, 5080 done
# Image, 5081 done
# Image, 5082 done
# Image, 5083 done
# Image, 5084 done
# Image, 5085 done
# Image, 5086 done
# Image, 5087 done
# Image, 5088 done
# Image, 5089 done
# Image, 5090 done
# Image, 5091 done
# Image, 5092 done
# Image, 5093 done
# Image, 5094 done
# Image, 5095 done
# Image, 5096 done
# Image, 5097 done
# Image, 5098 done
# Image, 5099 done
# Image, 5100 done
# Image, 5101 done
# Image, 5102 done
# Image, 5103 done
# Image, 5104 done
# Image, 5105 done
# Image, 5106 done
# Image, 5107 done
# Image, 5108 done
# Image, 5109 done
# Image, 5110 done
# Image, 5111 done
# Image, 5112 done
# Image, 5113 done
# Image, 5114 done
# Image, 5115 done
# Image, 5116 done
# Image, 5117 done
# Image, 5118 done
# Image, 5119 done
# Image, 5120 done
# Image, 5121 done
# Image, 5122 done
# Image, 5123 done
# Image, 5124 done
# Image, 5125 done
# Image, 5126 done
# Image, 5127 done
# Image, 5128 done
# Image, 5129 done
# Image, 5130 done
# Image, 5131 done
# Image, 5132 done
# Image, 5133 done
# Image, 5134 done
# Image, 5135 done
# Image, 5136 done
# Image, 5137 done
# Image, 5138 done
# Image, 5139 done
# Image, 5140 done
# Image, 5141 done
# Image, 5142 done
# Image, 5143 done
# Image, 5144 done
# Image, 5145 done
# Image, 5146 done
# Image, 5147 done
# Image, 5148 done
# Image, 5149 done
# Image, 5150 done
# Image, 5151 done
# Image, 5152 done
# Image, 5153 done
# Image, 5154 done
# Image, 5155 done
# Image, 5156 done
# Image, 5157 done
# Image, 5158 done
# Image, 5159 done
# Image, 5160 done
# Image, 5161 done
# Image, 5162 done
# Image, 5163 done
# Image, 5164 done
# Image, 5165 done
# Image, 5166 done
# Image, 5167 done
# Image, 5168 done
# Image, 5169 done
# Image, 5170 done
# Image, 5171 done
# Image, 5172 done
# Image, 5173 done
# Image, 5174 done
# Image, 5175 done
# Image, 5176 done
# Image, 5177 done
# Image, 5178 done
# Image, 5179 done
# Image, 5180 done
# Image, 5181 done
# Image, 5182 done
# Image, 5183 done
# Image, 5184 done
# Image, 5185 done
# Image, 5186 done
# Image, 5187 done
# Image, 5188 done
# Image, 5189 done
# Image, 5190 done
# Image, 5191 done
# Image, 5192 done
# Image, 5193 done
# Image, 5194 done
# Image, 5195 done
# Image, 5196 done
# Image, 5197 done
# Image, 5198 done
# Image, 5199 done
# Image, 5200 done
# Image, 5201 done
# Image, 5202 done
# Image, 5203 done
# Image, 5204 done
# Image, 5205 done
# Image, 5206 done
# Image, 5207 done
# Image, 5208 done
# Image, 5209 done
# Image, 5210 done
# Image, 5211 done
# Image, 5212 done
# Image, 5213 done
# Image, 5214 done
# Image, 5215 done
# Image, 5216 done
# Image, 5217 done
# Image, 5218 done
# Image, 5219 done
# Image, 5220 done
# Image, 5221 done
# Image, 5222 done
# Image, 5223 done
# Image, 5224 done
# Image, 5225 done
# Image, 5226 done
# Image, 5227 done
# Image, 5228 done
# Image, 5229 done
# Image, 5230 done
# Image, 5231 done
# Image, 5232 done
# Image, 5233 done
# Image, 5234 done
# Image, 5235 done
# Image, 5236 done
# Image, 5237 done
# Image, 5238 done
# Image, 5239 done
# Image, 5240 done
# Image, 5241 done
# Image, 5242 done
# Image, 5243 done
# Image, 5244 done
# Image, 5245 done
# Image, 5246 done
# Image, 5247 done
# Image, 5248 done
# Image, 5249 done
# Image, 5250 done
# Image, 5251 done
# Image, 5252 done
# Image, 5253 done
# Image, 5254 done
# Image, 5255 done
# Image, 5256 done
# Image, 5257 done
# Image, 5258 done
# Image, 5259 done
# Image, 5260 done
# Image, 5261 done
# Image, 5262 done
# Image, 5263 done
# Image, 5264 done
# Image, 5265 done
# Image, 5266 done
# Image, 5267 done
# Image, 5268 done
# Image, 5269 done
# Image, 5270 done
# Image, 5271 done
# Image, 5272 done
# Image, 5273 done
# Image, 5274 done
# Image, 5275 done
# Image, 5276 done
# Image, 5277 done
# Image, 5278 done
# Image, 5279 done
# Image, 5280 done
# Image, 5281 done
# Image, 5282 done
# Image, 5283 done
# Image, 5284 done
# Image, 5285 done
# Image, 5286 done
# Image, 5287 done
# Image, 5288 done
# Image, 5289 done
# Image, 5290 done
# Image, 5291 done
# Image, 5292 done
# Image, 5293 done
# Image, 5294 done
# Image, 5295 done
# Image, 5296 done
# Image, 5297 done
# Image, 5298 done
# Image, 5299 done
# Image, 5300 done
# Image, 5301 done
# Image, 5302 done
# Image, 5303 done
# Image, 5304 done
# Image, 5305 done
# Image, 5306 done
# Image, 5307 done
# Image, 5308 done
# Image, 5309 done
# Image, 5310 done
# Image, 5311 done
# Image, 5312 done
# Image, 5313 done
# Image, 5314 done
# Image, 5315 done
# Image, 5316 done
# Image, 5317 done
# Image, 5318 done
# Image, 5319 done
# Image, 5320 done
# Image, 5321 done
# Image, 5322 done
# Image, 5323 done
# Image, 5324 done
# Image, 5325 done
# Image, 5326 done
# Image, 5327 done
# Image, 5328 done
# Image, 5329 done
# Image, 5330 done
# Image, 5331 done
# Image, 5332 done
# Image, 5333 done
# Image, 5334 done
# Image, 5335 done
# Image, 5336 done
# Image, 5337 done
# Image, 5338 done
# Image, 5339 done
# Image, 5340 done
# Image, 5341 done
# Image, 5342 done
# Image, 5343 done
# Image, 5344 done
# Image, 5345 done
# Image, 5346 done
# Image, 5347 done
# Image, 5348 done
# Image, 5349 done
# Image, 5350 done
# Image, 5351 done
# Image, 5352 done
# Image, 5353 done
# Image, 5354 done
# Image, 5355 done
# Image, 5356 done
# Image, 5357 done
# Image, 5358 done
# Image, 5359 done
# Image, 5360 done
# Image, 5361 done
# Image, 5362 done
# Image, 5363 done
# Image, 5364 done
# Image, 5365 done
# Image, 5366 done
# Image, 5367 done
# Image, 5368 done
# Image, 5369 done
# Image, 5370 done
# Image, 5371 done
# Image, 5372 done
# Image, 5373 done
# Image, 5374 done
# Image, 5375 done
# Image, 5376 done
# Image, 5377 done
# Image, 5378 done
# Image, 5379 done
# Image, 5380 done
# Image, 5381 done
# Image, 5382 done
# Image, 5383 done
# Image, 5384 done
# Image, 5385 done
# Image, 5386 done
# Image, 5387 done
# Image, 5388 done
# Image, 5389 done
# Image, 5390 done
# Image, 5391 done
# Image, 5392 done
# Image, 5393 done
# Image, 5394 done
# Image, 5395 done
# Image, 5396 done
# Image, 5397 done
# Image, 5398 done
# Image, 5399 done
# Image, 5400 done
# Image, 5401 done
# Image, 5402 done
# Image, 5403 done
# Image, 5404 done
# Image, 5405 done
# Image, 5406 done
# Image, 5407 done
# Image, 5408 done
# Image, 5409 done
# Image, 5410 done
# Image, 5411 done
# Image, 5412 done
# Image, 5413 done
# Image, 5414 done
# Image, 5415 done
# Image, 5416 done
# Image, 5417 done
# Image, 5418 done
# Image, 5419 done
# Image, 5420 done
# Image, 5421 done
# Image, 5422 done
# Image, 5423 done
# Image, 5424 done
# Image, 5425 done
# Image, 5426 done
# Image, 5427 done
# Image, 5428 done
# Image, 5429 done
# Image, 5430 done
# Image, 5431 done
# Image, 5432 done
# Image, 5433 done
# Image, 5434 done
# Image, 5435 done
# Image, 5436 done
# Image, 5437 done
# Image, 5438 done
# Image, 5439 done
# Image, 5440 done
# Image, 5441 done
# Image, 5442 done
# Image, 5443 done
# Image, 5444 done
# Image, 5445 done
# Image, 5446 done
# Image, 5447 done
# Image, 5448 done
# Image, 5449 done
# Image, 5450 done
# Image, 5451 done
# Image, 5452 done
# Image, 5453 done
# Image, 5454 done
# Image, 5455 done
# Image, 5456 done
# Image, 5457 done
# Image, 5458 done
# Image, 5459 done
# Image, 5460 done
# Image, 5461 done
# Image, 5462 done
# Image, 5463 done
# Image, 5464 done
# Image, 5465 done
# Image, 5466 done
# Image, 5467 done
# Image, 5468 done
# Image, 5469 done
# Image, 5470 done
# Image, 5471 done
# Image, 5472 done
# Image, 5473 done
# Image, 5474 done
# Image, 5475 done
# Image, 5476 done
# Image, 5477 done
# Image, 5478 done
# Image, 5479 done
# Image, 5480 done
# Image, 5481 done
# Image, 5482 done
# Image, 5483 done
# Image, 5484 done
# Image, 5485 done
# Image, 5486 done
# Image, 5487 done
# Image, 5488 done
# Image, 5489 done
# Image, 5490 done
# Image, 5491 done
# Image, 5492 done
# Image, 5493 done
# Image, 5494 done
# Image, 5495 done
# Image, 5496 done
# Image, 5497 done
# Image, 5498 done
# Image, 5499 done
# Image, 5500 done
# Image, 5501 done
# Image, 5502 done
# Image, 5503 done
# Image, 5504 done
# Image, 5505 done
# Image, 5506 done
# Image, 5507 done
# Image, 5508 done
# Image, 5509 done
# Image, 5510 done
# Image, 5511 done
# Image, 5512 done
# Image, 5513 done
# Image, 5514 done
# Image, 5515 done
# Image, 5516 done
# Image, 5517 done
# Image, 5518 done
# Image, 5519 done
# Shape of original training data for ADASYN: (5482, 227, 227) with corresponding y: (5482,)
# Shape of augmented training data for ADASYN: (38374, 227, 227) with corresponding y: (38374,)
# Shape of original training data for RandomOverSampler: (5520, 227, 227) with corresponding y: (5520,)
# Shape of augmented training data for RandomOverSampler: (38640, 227, 227) with corresponding y: (38640,)

# %%
aug_names = ["Original", "Rotate90", "Rotate180", "Rotate270", "Flip Horizontal", "Flip Vertical", "Zoom"]
class_names = ["other", "crater", "dark dune", "slope streak", "bright dune", "impact ejecta", "swiss cheese", "spider"]

# function that generates 10 random integers from numpy array that are divisible by 7
def generate_random_integers(X, n):
    random_integers = []
    while len(random_integers) < n:
        integer = np.random.randint(0, len(X))
        if integer % 7 == 0:
            random_integers.append(integer)
    return random_integers

# create function that takes 10 random images from the augmented training data and plots them
def plot_augmented_images(X, y, aug_names, class_names, num_images):
    indices = generate_random_integers(X, num_images)
    fig, axes = plt.subplots(len(indices), 7, figsize=(15, 15))
    c = 0
    for i in indices:
        for j in range(7):
            axes[c, j].imshow(X[i+j], cmap="gray")
            axes[c, j].set_xticks([])
            axes[c, j].set_yticks([])
            
            axes[c, j].set_xlabel(aug_names[j] + " " + str(int(i+j)))
            if j == 0:
                axes[c, j].set_ylabel(class_names[int(y[i+j])])
        c += 1
    plt.show()

# %%
plot_augmented_images(X_t_A_A, y_t_A_A, aug_names, class_names, 7)

# %%
def shuffle_data(x, y):
    assert x.shape[0] == y.shape[0]
    p = np.random.permutation(x.shape[0])
    return x[p], y[p], p

# %% [markdown]
# # final training data

# %%
X_t_A_A_S, y_t_A_A_S, p = shuffle_data(X_t_A_A, y_t_A_A)
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
X_t_O_A_S, y_t_O_A_S, p = shuffle_data(X_t_O_A, y_t_O_A)

# %% [markdown]
# # 8 Apply Models

# %%
#!pip install tensorflow
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix

import numpy as np
import seaborn as sns

np.random.seed(1000)
# Out:
# 2023-05-15 18:07:30.429298: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def model_evaluation(model, history, X_test, y_test, class_names):
    sns.lineplot(data=history.history['accuracy'], label='accuracy')
    sns.lineplot(data=history.history['val_accuracy'], label='val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0.5, 1])
    plt.legend(loc='lower right')
    plt.show()

    test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)
    print("Accuracy on the training set:", test_acc)
    y_pred_prob = model.predict(X_test)
    y_pred_class = y_pred_prob.argmax(axis=-1)

    print(classification_report(y_pred_class, y_test, target_names=class_names))
    fig = plt.figure(figsize=(10, 6))
    sns.heatmap(confusion_matrix(y_pred_class, y_test), xticklabels=class_names, yticklabels=class_names, annot=True)
    plt.show()

# %% [markdown]
# # 8.1 AlexNet Oversampled Data

# %%
alex_O = Sequential()

# 1st Convolutional Layer
alex_O.add(Conv2D(filters=96, input_shape=(227, 227, 1), kernel_size=(11,11), strides=(4,4), padding='valid', activation='relu'))
# First Layer has 96 Filters, the input shape is 227x227x1, 
# the kernel size is 11x11, the stride is 4x4, and the padding is valid
# Relu is the activation function
# ==> Output: 55x55x96

# Max Pooling Layer
alex_O.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='valid'))
# The Pool Size is 3x3, the stride is 2x2, and the padding is valid
# ==> Output: 27x27x96

# 2nd Convolutional Layer
alex_O.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='valid', activation='relu'))
# Second Layer has 256 Filters, the kernel size is 5x5, 
# the stride is 1x1, and the padding is valid
# Relu is the activation function
# ==> Output: 23x23x256

# Max Pooling Layer
alex_O.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='valid'))
# The Pool Size is 3x3, the stride is 2x2, and the padding is valid
# ==> Output: 11x11x256

# 3rd Convolutional Layer
alex_O.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu'))
# Third Layer has 384 Filters, the kernel size is 3x3,
# the stride is 1x1, and the padding is valid
# Relu is the activation function
# ==> Output: 9x9x384

# 4th Convolutional Layer
alex_O.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu'))
# Fourth Layer has 384 Filters, the kernel size is 3x3,
# the stride is 1x1, and the padding is valid
# Relu is the activation function
# ==> Output: 7x7x384

# 5th Convolutional Layer
alex_O.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu'))
# Fifth Layer has 256 Filters, the kernel size is 3x3,
# the stride is 1x1, and the padding is valid
# Relu is the activation function
# ==> Output: 5x5x256

# Max Pooling Layer
alex_O.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='valid'))
# The Pool Size is 3x3, the stride is 2x2, and the padding is valid
# ==> Output: 2x2x256

# Passing it to a Fully Connected layer
alex_O.add(Flatten())
# ==> Output: 1024

# 1st Fully Connected Layer
alex_O.add(Dense(4096, input_shape=(227*227*1,), activation='relu'))
# First Fully Connected Layer has 4096 neurons, the input shape is 227x227x1
# Relu is the activation function
# ==> Output: 4096

# Add Dropout to prevent overfitting
alex_O.add(Dropout(0.5))

# 2nd Fully Connected Layer
alex_O.add(Dense(4096, activation='relu'))
# Second Fully Connected Layer has 4096 neurons, the input shape is 4096
# Relu is the activation function
# ==> Output: 4096

# Add Dropout
alex_O.add(Dropout(0.5))

# Output Layer
alex_O.add(Dense(8))
alex_O.add(Activation('softmax'))

# %%
alex_O.summary()

# %%
# Hyperparameters
learning_rate = 0.01
weight_decay = 0.0005
momentum = 0.9
epochs = 90
batch_size = 128

# Optimizer
optimizer = keras.optimizers.SGD(learning_rate=learning_rate, decay=weight_decay, momentum=momentum, nesterov=True)

# Loss Function
loss_function = keras.losses.SparseCategoricalCrossentropy()

# Compile Model
alex_O.compile(optimizer=optimizer, loss=loss_function, metrics=['accuracy'])

# Training
history_O = alex_O.fit(X_t_O_A_S, y_t_O_A_S, batch_size=32, epochs=10, validation_data=(X_val, y_val))

# %%
model_evaluation(alex_O, history_O, X_test, y_test, class_names)

# %% [markdown]
# # 8.2 AlexNet ADASYN DATA

# %%
alex_A = Sequential()

# 1st Convolutional Layer
alex_A.add(Conv2D(filters=96, input_shape=(227, 227, 1), kernel_size=(11,11), strides=(4,4), padding='valid', activation='relu'))
# First Layer has 96 Filters, the input shape is 227x227x1, 
# the kernel size is 11x11, the stride is 4x4, and the padding is valid
# Relu is the activation function
# ==> Output: 55x55x96

# Max Pooling Layer
alex_A.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='valid'))
# The Pool Size is 3x3, the stride is 2x2, and the padding is valid
# ==> Output: 27x27x96

# 2nd Convolutional Layer
alex_A.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='valid', activation='relu'))
# Second Layer has 256 Filters, the kernel size is 5x5, 
# the stride is 1x1, and the padding is valid
# Relu is the activation function
# ==> Output: 23x23x256

# Max Pooling Layer
alex_A.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='valid'))
# The Pool Size is 3x3, the stride is 2x2, and the padding is valid
# ==> Output: 11x11x256

# 3rd Convolutional Layer
alex_A.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu'))
# Third Layer has 384 Filters, the kernel size is 3x3,
# the stride is 1x1, and the padding is valid
# Relu is the activation function
# ==> Output: 9x9x384

# 4th Convolutional Layer
alex_A.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu'))
# Fourth Layer has 384 Filters, the kernel size is 3x3,
# the stride is 1x1, and the padding is valid
# Relu is the activation function
# ==> Output: 7x7x384

# 5th Convolutional Layer
alex_A.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu'))
# Fifth Layer has 256 Filters, the kernel size is 3x3,
# the stride is 1x1, and the padding is valid
# Relu is the activation function
# ==> Output: 5x5x256

# Max Pooling Layer
alex_A.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='valid'))
# The Pool Size is 3x3, the stride is 2x2, and the padding is valid
# ==> Output: 2x2x256

# Passing it to a Fully Connected layer
alex_A.add(Flatten())
# ==> Output: 1024

# 1st Fully Connected Layer
alex_A.add(Dense(4096, input_shape=(227*227*1,), activation='relu'))
# First Fully Connected Layer has 4096 neurons, the input shape is 227x227x1
# Relu is the activation function
# ==> Output: 4096

# Add Dropout to prevent overfitting
alex_A.add(Dropout(0.4))

# 2nd Fully Connected Layer
alex_A.add(Dense(4096, activation='relu'))
# Second Fully Connected Layer has 4096 neurons, the input shape is 4096
# Relu is the activation function
# ==> Output: 4096

# Add Dropout
alex_A.add(Dropout(0.4))

# Output Layer
alex_A.add(Dense(8))
alex_A.add(Activation('softmax'))

# %%
alex_A.summary()

# %%
# Hyperparameters
learning_rate = 0.01
weight_decay = 0.0005
momentum = 0.9
epochs = 90
batch_size = 128

# Optimizer
optimizer = keras.optimizers.SGD(learning_rate=learning_rate, decay=weight_decay, momentum=momentum, nesterov=True)

# Loss Function
loss_function = keras.losses.SparseCategoricalCrossentropy()

# Compile Model
alex_A.compile(optimizer=optimizer, loss=loss_function, metrics=['accuracy'])

# Training
history_A = alex_A.fit(X_t_A_A_S, y_t_A_A_S, batch_size=32, epochs=10, validation_data=(X_val, y_val))

# %%
model_evaluation(alex_A, history_A, X_test, y_test, class_names)

# %% [markdown]
# # 8.2 GoogleNet Oversampled Data

# %%
def inception_module(x, filters_1x1, filters_3x3_reduce, filters_3x3, filters_5x5_reduce, filters_5x5, filters_pool_proj):
    path1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu')(x)
    path2 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu')(x)
    path2 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu')(path2)
    path3 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu')(x)
    path3 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu')(path3)
    path4 = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    path4 = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu')(path4)
    return concatenate([path1, path2, path3, path4], axis=-1)

def GoogLeNet():
    input_layer = Input(shape=(227, 227, 1))

    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(input_layer)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
    x = Conv2D(64, (1, 1), strides=(1, 1), padding='same', activation='relu')(x)
    x = Conv2D(192, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
    x = inception_module(x, 64, 96, 128, 16, 32, 32)
    x = inception_module(x, 128, 128, 192, 32, 96, 64)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
    x = inception_module(x, 192, 96, 208, 16, 48, 64)
    x = inception_module(x, 160, 112, 224, 24, 64, 64)
    x = inception_module(x, 128, 128, 256, 24, 64, 64)
    x = inception_module(x, 112, 144, 288, 32, 64, 64)
    x = inception_module(x, 256, 160, 320, 32, 128, 128)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
    x = inception_module(x, 256, 160, 320, 32, 128, 128)
    x = inception_module(x, 384, 192, 384, 48, 128, 128)

    x = AveragePooling2D(pool_size=(7, 7), strides=(1, 1), padding='valid')(x)
    x = Dropout(0.4)(x)
    x = Flatten()(x)
    x = Dense(1000, activation='sigmoid')(x)
    output_layer = Dense(8, activation='softmax')(x)

    # Define the model
    model_googlenet = Model(input_layer, output_layer)

    # Return the model
    return model_googlenet

# %%
# Create the model
google_A = GoogLeNet()

# %%
# Hyperparameters
learning_rate = 0.01
momentum = 0.9

# Coompile the model
# Optimizer
optimizer = keras.optimizers.SGD(learning_rate=learning_rate, momentum=momentum, nesterov=True)

# Loss Function
loss_function = keras.losses.SparseCategoricalCrossentropy() 

# Compile Model
google_A.compile(optimizer=optimizer, loss=loss_function, metrics=["accuracy"])

# Fit the model to the training data
history_G_A = google_A.fit(X_t_A_A_S, y_t_A_A_S, batch_size=32, epochs=10, validation_data=(X_val, y_val))

# %%
model_evaluation(alex_A, google_A, X_test, y_test, class_names)

# %% [markdown]
# # Benchmark CNN

# %%
# !pip install keras
# !pip install tensorflow
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import reciprocal
import numpy as np
import keras

# %%
def benchmark_model(n_hidden=1,n_neurons=30, learning_rate=3e-4):
    benchmark = Sequential()
    benchmark.add(Conv2D(32, kernel_size=(3,3),activation='relu',input_shape=(227,227,1))) 
    benchmark.add(Conv2D(64, (3, 3), activation='relu')) 
    benchmark.add(MaxPooling2D(pool_size=(2, 2))) 
    benchmark.add(Dropout(0.25))
    benchmark.add(Flatten())
    
    for layer in range(n_hidden):
        benchmark.add(Dense(n_neurons, activation='relu'))
        benchmark.add(Dropout(0.5))
        benchmark.add(Dense(num_classes=8, activation='softmax'))
        
    optimizer = keras.optimizers.Adam(lr=learning_rate)
    benchmark.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"]) 
    return benchmark

# %%
def random_search (X_train, y_train, X_valid, y_valid):
    param = {"n_hidden": [1, 2, 3, 41],
    "n_neurons": np.arange(30, 300),
    "learning_rate": reciprocal(3e-4, 3e-2),
    "batch size": [32, 64, 128, 256, 512]
    }

    keras_classifier = KerasClassifier(build_fn=benchmark_model)
    keras_rand_search = RandomizedSearchCV(keras_classifier, param, n_iter=32, cv=5, scoring="accuracy", n_jobs=-1, verbose=True)
    keras_rand_search.fit(X_train, y_train, epochs=1, validation_data=(X_valid, y_valid), callbacks=[keras.callbacks.EarlyStopping(patience=10)])
# Out:
#   Cell In[1], line 19
#     keras_rand_search.fit(X_t_A_A_S, y_t_A-, epochs=1,
#                                            ^
# SyntaxError: invalid syntax

# %%
from keras.utils import to_categorical
def one_hot_encode (y) :

    # use the function
    y_t_A_A_S = one_hot_encode (y_t_A_A_S)
    return to_categorical(y)

# %%
random_search(X_t_A_A_S, Y_t_A_A_S, X_val, y_val)
